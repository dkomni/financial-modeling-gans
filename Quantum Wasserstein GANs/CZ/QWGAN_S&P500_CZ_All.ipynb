# %% [markdown]
# # Generating Financial Time Series with a Quantum Wasserstein GAN
#
# ### PQC Characteristics
#  - Rotation layers (RX*RY*RZ - Parameterized)
#  - Entangling layers (CZ - All-to-all - Not Parameterized)

# %%
# hide tensorflow warnings on GPU execution (we will use CPU)
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

# disable GPU usage
import os
os.environ["CUDA_VISIBLE_DEVICES"] = ""

import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm, wasserstein_distance, probplot
from scipy.special import lambertw
from statsmodels.graphics import tsaplots
import statsmodels.api as sm
import time
import cirq, random, sympy
import tensorflow_quantum as tfq
import tensorflow as tf
from cirq.contrib.svg import SVGCircuit
from cirq.circuits import InsertStrategy

# limit GPU memory growth to avoid OUT_OF_MEMORY issues (before initializing GPU -- if used)
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e:
        print(e)

# download daily S&P 500 data from Yahoo Finance from 1/1/2008 since 31/12/2022
sp500 = yf.download('^GSPC', start='2008-01-01', end='2022-12-31')

# pandas DataFrame with 6 columns, (Open, High, Low, Close, Adj Close, and Volume values)
# extract daily closing values as a numpy array
sp500_close = tf.convert_to_tensor(sp500['Close'].values)

# display the shape of the numpy array
print('S&P500 shape (total days): ', tf.shape(sp500_close))

# check if GPU is available
print("GPU Available:", tf.config.list_physical_devices('GPU'))

# check which GPU is being used
print("GPU Device:", tf.test.gpu_device_name())

df = sp500.reset_index()
date = df['Date']
# plot the S&P 500 data
plt.plot(date, sp500_close)
plt.xlabel('Days')
plt.ylabel('S&P 500 Closing Value')
plt.title('S&P 500 Index')
plt.grid()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# S&P500 shape (total days):  tf.Tensor([3777], shape=(1,), dtype=int32)
# GPU Available: []
# GPU Device:

# %%
# direct returns over time
sp500_direct_r = sp500_close[1:] - sp500_close[:-1]
    
# logarithmic returns over time
sp500_log_r = np.log(sp500_close[1:]) - np.log(sp500_close[:-1])

# plot the graphs side-by-side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))

axes[0].plot(date[1:], sp500_direct_r)
axes[0].set_title('S&P 500 Index Direct Returns')
axes[0].grid()

axes[1].plot(date[1:], sp500_log_r)
axes[1].set_title('S&P 500 Index Log Returns')
axes[1].grid()
    
# Show the plot
plt.show()

# %%
# plot the graphs side-by-side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))

# density of log-returns
bin_edges = np.linspace(-0.05, 0.05, num=50)  # define the bin edges
bin_width = bin_edges[1] - bin_edges[0]
bin_edges = np.append(bin_edges, bin_edges[-1] + bin_width)
axes[0].hist(sp500_log_r, bins=bin_edges, density=True, width=0.001, label='Log-returns density')
axes[0].grid()

# normal distribution with same mean and standard deviation as log-returns
mu = np.mean(sp500_log_r)
sigma = np.std(sp500_log_r)

# Generate a set of points x
x = np.linspace(-0.05, 0.05, 100)

# Generate the Gaussian PDF for the points x with same mean and standard deviation as the log-returns
pdf = norm.pdf(x, mu, sigma)

# plot the Gaussian PDF
axes[0].plot(x, pdf, 'r', label='Gaussian distribution')
axes[0].legend()

# plot in logarithmic scale
axes[1].hist(sp500_log_r, bins=bin_edges, density=True, width=0.001, log=True)
axes[1].grid()

# plot the Gaussian PDF in logarithmic scale
axes[1].semilogy(x, pdf, 'r')

plt.show()

# %%
# convert the S&P 500 log returns to a TensorFlow tensor
sp500_log_r_tf = tf.convert_to_tensor(sp500_log_r)
# plot the ACF for the specified lags
tsaplots.plot_acf(sp500_log_r_tf, lags=18, zero=False)
plt.xlabel('Lags')
plt.title('ACF S&P 500 Log-Returns')
plt.ylabel(r'$\rho$')
plt.grid()
plt.show()

# %%
# plot the ACF of absolute log-returns for the specified lags
tsaplots.plot_acf(tf.abs(sp500_log_r_tf), lags=18, zero=False)
plt.xlabel('Lags')
plt.title('ACF S&P 500 Absolute Log-Returns')
plt.ylabel(r'$\rho_{abs}$')
plt.grid()
plt.show()

# %%
lags = range(1, 19)
lev = []
for lag in lags:
    # slice the tensors to get the appropriate lagged sequences
    r_t = sp500_log_r_tf[:-lag]
    squared_lag_r = tf.square(tf.abs(sp500_log_r_tf[lag:]))
                
    # calculate the leverage effect
    # calculate the correlation coefficient
    correlation_matrix = np.corrcoef(r_t, squared_lag_r)
    lev.append(correlation_matrix[0, 1])

# plot the the levarage effect
plt.plot(lev)
plt.title('Leverage Effect S&P 500')
plt.xlabel('Lags')
plt.ylabel(r'$L(\tau)$')
plt.grid()
plt.show()

# %%
# Generate the Q-Q plot
plt.figure(figsize=(6, 4))
probplot(sp500_log_r_tf, dist='norm', plot=plt)
plt.title('Q-Q Plot - S&P 500 Log Returns')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Implementation

# %% [markdown]
# ### Data Pre-Processing

# %% [markdown]
# #### (1) Normalization

# %%
def normalize(data):
    mu = tf.reduce_mean(data)
    std = tf.math.reduce_std(data)
    
    return (data - mu)/std

# %%
def denormalize(norm_data, mu_original, std_original):
    return norm_data*std_original + mu_original

# %%
# normalize the log-returns
sp500_norm_r = normalize(sp500_log_r_tf)
# display the mean and standard deviation of the original log-returns
print(f'Original S&P 500 log-returns mean = {tf.reduce_mean(sp500_log_r_tf)}, std = {tf.math.reduce_std(sp500_log_r_tf)}')
# display the mean and standard deviation of the normalized log-returns
print(f'Normalized S&P 500 log-returns mean = {tf.reduce_mean(sp500_norm_r)}, std = {tf.math.reduce_std(sp500_norm_r)}')
# Out:
# Original S&P 500 log-returns mean = 0.0002584054849133775, std = 0.013199541207181623
# Normalized S&P 500 log-returns mean = -1.8817339400426382e-18, std = 0.9999999999999999

# %%
print('Original Data Min-Max')
print(tf.reduce_min(sp500_log_r_tf).numpy(), tf.reduce_max(sp500_log_r_tf).numpy())

print('Normalized Data Min-Max')
print(tf.reduce_min(sp500_norm_r).numpy(), tf.reduce_max(sp500_norm_r).numpy())
# Out:
# Original Data Min-Max
# -0.12765219747281709 0.10957196759533883
# Normalized Data Min-Max
# -9.690534007965118 8.281618307381017

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(7,4))

# density of log-returns
bin_edges = np.linspace(-6, 6, num=100)  # define the bin edges
bin_width = bin_edges[1] - bin_edges[0]
bin_edges = np.append(bin_edges, bin_edges[-1] + bin_width)
axes.hist(sp500_norm_r, bins=bin_edges, density=True, width=0.1, label='Normalized density')
axes.grid()

# normal distribution with same mean and standard deviation as log-returns
mu = np.mean(sp500_norm_r)
sigma = np.std(sp500_norm_r)

# Generate a set of points x
x = np.linspace(-6, 6, 100)

# Generate the Gaussian PDF for the points x with same mean and standard deviation as the log-returns
pdf = norm.pdf(x, mu, sigma)

# plot the Gaussian PDF
axes.plot(x, pdf, 'r', label='Gaussian')
axes.legend()

plt.show()

# %% [markdown]
# #### (2) Inverse Lambert W Transform

# %%
def inverse_lambert_w_transform(data, delta):
    """
    Apply inverse Lambert W transform to the input data using the specified delta value.

    Parameters:
    - data: Input data tensor
    - delta: Delta value for the transform (tail parameter)

    Returns:
    - Transformed data array
    """
    sign = tf.sign(tf.cast(data, dtype=tf.float64))  
    transformed_data = sign * tf.cast(tf.sqrt(lambertw(delta * data ** 2).real / delta), dtype=tf.float64)
   
    return transformed_data

def lambert_w_transform(transformed_data, delta, clip_low=-12.0, clip_high=11.0):
    """
    Transform the Gaussianized data back to its original state.

    Parameters:
    - transformed_data: Input data array which was transformed using inverse Lambert W
    - delta: Delta value for the transform (tail parameter)

    Returns:
    - Original Data
    """
    reversed_data = transformed_data*tf.cast(tf.exp((delta/2) * transformed_data ** 2), dtype=tf.float64)
    return tf.clip_by_value(reversed_data, clip_low, clip_high)

# %%
# apply inverse Lambert W transform to the normalized log-returns
transformed_sp500 = inverse_lambert_w_transform(sp500_norm_r, 1)

fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(7,4))

# density of normalized log-returns
bin_edges = np.linspace(-3, 3, num=50)  # define the bin edges
bin_width = bin_edges[1] - bin_edges[0]
bin_edges = np.append(bin_edges, bin_edges[-1] + bin_width)
axes.hist(transformed_sp500, bins=bin_edges, density=True, width=0.1, label='Transformed log-returns')
axes.grid()

# normal distribution with same mean and standard deviation as log-returns
mu = np.mean(transformed_sp500)
sigma = np.std(transformed_sp500)

# Generate a set of points x
x = np.linspace(-3, 3, 100)

# Generate the Gaussian PDF for the points x with same mean and standard deviation as the normalized log-returns
pdf = norm.pdf(x, mu, sigma)

# plot the Gaussian PDF
axes.plot(x, pdf, 'r', label='Gaussian')
axes.legend()

plt.show()

# %%
# Generate the Q-Q plot
plt.figure(figsize=(6, 4))
probplot(transformed_sp500, dist='norm', plot=plt)
plt.title('Q-Q Plot - Transformed S&P 500 Log Returns')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')
plt.grid(True)
plt.show()

# %%
print('Transformed Data Min-Max')
print(tf.reduce_min(transformed_sp500).numpy(), tf.reduce_max(transformed_sp500).numpy())
# Out:
# Transformed Data Min-Max
# -1.8267935183456632 1.7599676089068168

# %%
print('Transformed data mean: ', tf.reduce_mean(transformed_sp500).numpy())
print('Transformed data std: ', tf.math.reduce_std(transformed_sp500).numpy())
# Out:
# Transformed data mean:  0.014927970271913928
# Transformed data std:  0.5588396501296408

# %% [markdown]
# #### (3) Scale to [-1,1]
#
# Necessary scaling to match the range of expectation values.

# %%
min_val = tf.reduce_min(transformed_sp500)
max_val = tf.reduce_max(transformed_sp500)
scaled_data = -1.0 + 2.0 * (transformed_sp500 - min_val) / (max_val - min_val)

# %%
print(f'Scaled Normalized Transformed log-returns mean = {tf.reduce_mean(scaled_data)}, std = {tf.math.reduce_std(scaled_data)}')
print('Scaled Normalized Transformed log-returns min-max: ', tf.reduce_min(scaled_data).numpy(), tf.reduce_max(scaled_data).numpy())
# Out:
# Scaled Normalized Transformed log-returns mean = 0.026955196220924363, std = 0.31161241593901257
# Scaled Normalized Transformed log-returns min-max:  -1.0 1.0

# %%
# a function to scale back from [-1,1] to the previous range
def rescale(scaled_data, rescaled_data):
    min_val = tf.reduce_min(rescaled_data)
    previous_data = 0.5 * (scaled_data + 1.0) * (max_val - min_val) + min_val
    
    return previous_data

# %% [markdown]
# #### (4) Rolling Window

# %%
def rolling_window(data, m, s):
    return tf.map_fn(lambda i: data[i:i+m], tf.range(0, len(data) - m + 1, s), dtype=tf.float64)

# %% [markdown]
# ## qGAN

# %%
class qGAN(tf.keras.Model):
    
    def __init__(self, num_epochs, batch_size, window_length, n_critic, gp, num_layers, num_qubits):
        super(qGAN, self).__init__()
        
        # classical hyperparameters
        self.num_epochs = num_epochs
        self.batch_size = batch_size
        self.window_length = window_length
        self.n_critic = n_critic
        self.gp = gp
        
        # quantum hyperparameters
        # one layer corresponds to a rotation and an entangling layer together
        self.num_layers = num_layers
        self.num_qubits = num_qubits
        
        # quantum circuit settings
        self.qubits = cirq.GridQubit.rect(1, num_qubits)
        # create the set of Pauli strings to measure -> {X1, Z1, X2, Z2, etc}
        # X1 means we measure the first qubit only with X, Z1 the first qubit only with Z and so on...
        self.measurements = []
        for qubit in self.qubits:
            self.measurements.append(cirq.X(qubit))
            self.measurements.append(cirq.Z(qubit))
            
        # number of parameters of the PQC and re-uploading layers
        self.num_params = self.count_params()
        
        # define the trainable parameters of the PQC main and re-uploading layers (trainable)
        self.params_pqc = [sympy.Symbol(f'theta{i}') for i in range(self.num_params)]
        
        # define the classical critic network (CNN)
        self.critic = self.define_critic_model(window_length)
        # define the quantum generator network (PQC)
        self.generator = self.define_generator_model()
        
        # monitoring purposes
        # average critic and generator losses for each epoch
        self.critic_loss_avg = []
        self.generator_loss_avg = []
        # Earth's mover distance (EMD) for each epoch
        self.emd_avg = []
        # stylized facts RMSEs for each epoch
        self.acf_avg = []
        self.vol_avg = []
        self.lev_avg = []
        
    ####################################################################################
    #
    # count the parameters of the quantum circuit
    #
    ####################################################################################
    def count_params(self):
        
        # rotation layer with Rx, Ry, Rz has 3N parameters, where N is the number of qubits
        # the entangling layer is not parameterized
        num_params_pqc = 3*self.num_qubits*self.num_layers
        
        # also, count the parameters of the re-uploading layer that is sandwiched between rotation-entangling layers
        # there is one re-uploading layer after each rotation-entangling layer with a parameterized Rx gate,
        # so the number of parameters is equal to the number of qubits for each re-uploading layer
        num_params_upload = self.num_layers*self.num_qubits
        
        # the last layer of the PQC is a rotation layer
        num_params_pqc += 3*self.num_qubits
                    
        return num_params_pqc+num_params_upload
    
    ####################################################################################
    #
    # the classical critic model as a convolutional network
    #
    ####################################################################################  
    def define_critic_model(self, window_length):
        model = tf.keras.Sequential()
        model.add(tf.keras.layers.Conv1D(filters=64, kernel_size=10, strides=1, input_shape=(window_length, 1), padding='same'))
        model.add(tf.keras.layers.LeakyReLU(alpha=0.1))

        model.add(tf.keras.layers.Conv1D(filters=128, kernel_size=10, strides=1, padding='same'))
        model.add(tf.keras.layers.LeakyReLU(alpha=0.1))

        model.add(tf.keras.layers.Conv1D(filters=128, kernel_size=10, strides=1, padding='same'))
        model.add(tf.keras.layers.LeakyReLU(alpha=0.1))
    
        model.add(tf.keras.layers.Flatten())
    
        model.add(tf.keras.layers.Dense(32, dtype=tf.float64))
        model.add(tf.keras.layers.LeakyReLU(alpha=0.1))
        model.add(tf.keras.layers.Dropout(0.2))
    
        model.add(tf.keras.layers.Dense(1, dtype=tf.float64))

        return model
    
    ####################################################################################
    #
    # the encoding layer: resolve the parameters by uniform noise values,
    # used to prepare the initial state for the generator circuit
    #
    ####################################################################################
    def encoding_layer(self, noise_params):
        
        return cirq.Circuit(cirq.Rx(rads=noise_params[i])(self.qubits[i]) for i in range(self.num_qubits))
        
    ####################################################################################
    #
    # the quantum generator as a PQC with All-to-all topology for the entangling layer
    #
    #################################################################################### 
    def define_generator_circuit(self):
        
        # cirq circuit 
        pqc = cirq.Circuit()
        
        # index for the parameter tensor of the PQC main and re-uploading layers
        idx = 0
        
        for layer in range(self.num_layers):
            ###############################################################
            #
            # single-qubit rotation layer
            #
            ###############################################################
            for qubit in self.qubits:
                pqc.append(cirq.Rx(rads=self.params_pqc[idx])(qubit))
                idx += 1
                pqc.append(cirq.Ry(rads=self.params_pqc[idx])(qubit))
                idx += 1
                pqc.append(cirq.Rz(rads=self.params_pqc[idx])(qubit))
                idx += 1
            
            ###############################################################
            #
            # entangling layer (not parameterized)
            #
            ###############################################################
            for qubit1 in range(self.num_qubits):
                for qubit2 in range(qubit1+1, self.num_qubits):
                    pqc.append(cirq.CZ(self.qubits[qubit1], self.qubits[qubit2]), strategy=InsertStrategy.NEW)
            
            ###############################################################
            #
            # re-uploading layer with Rx rotation
            # (set the strategy for better readability and understanding)
            #
            ###############################################################
            for i, qubit in enumerate(self.qubits):
                if i == 0:
                    pqc.append(cirq.Rx(rads=self.params_pqc[idx])(qubit), strategy=InsertStrategy.NEW)
                else:
                    pqc.append(cirq.Rx(rads=self.params_pqc[idx])(qubit), strategy=InsertStrategy.INLINE)
                idx += 1
                
        #####################################################################
        #
        # single-qubit rotation layer as the last layer before measurement
        #
        #####################################################################
        for qubit in self.qubits:
                pqc.append(cirq.Rx(rads=self.params_pqc[idx])(qubit))
                idx += 1
                pqc.append(cirq.Ry(rads=self.params_pqc[idx])(qubit))
                idx += 1
                pqc.append(cirq.Rz(rads=self.params_pqc[idx])(qubit))
                idx += 1 
        
        return pqc
    
    ####################################################################################
    #
    # the quantum generator model
    #
    #################################################################################### 
    def define_generator_model(self):
        # model input
        q_data_input = tf.keras.Input(shape=(), dtype=tf.dtypes.string)
        # define the tensorflow quantum layer (trainable)
        generator = tfq.layers.PQC(self.define_generator_circuit(), self.measurements, repetitions=1000)
        generator_output = generator(q_data_input)
        # tensorflow model
        model = tf.keras.Model(inputs=q_data_input, outputs=generator_output)
        
        return model
    
    #############################################################################
    #
    # compile model with given optimizers for critic and generator networks
    #
    #############################################################################
    def compile_QGAN(self, c_optimizer, g_optimizer):
        super(qGAN, self).compile()
        self.c_optimizer = c_optimizer
        self.g_optimizer = g_optimizer
        
    def train_qgan(self, gan_data, original_data, preprocessed_data, num_elements):
        """
        Parameters:
         - gan_data is the preprocessed dataset with windows for qGAN training
         - original_data is the original S&P 500 log-returns for evaluation of RMSEs (monitoring purposes)
         - preprocessed_data is the preprocessed log-returns without the last normalization step and without windows
          (for reversing the process of generated samples using the mean and std and evaluating the RMSEs)
        """
        for epoch in range(self.num_epochs):
            print(f'Processing epoch {epoch+1}/{self.num_epochs}')
            ################################################################
            #
            # Train the critic for n_critic iterations
            # Process 'batch_size' samples in each iteration
            #
            ################################################################
            # critic loss for 'n_critic' iterations
            critic_t_sum = 0
            for t in range(self.n_critic):
                # record the gradients
                with tf.GradientTape() as critic_tape:
                    # critic loss for 'batch_size' samples
                    critic_sum = 0
                    for i in range(self.batch_size):
                        ###########################################
                        #
                        # Sample real data and a latent variable
                        #
                        ###########################################
                        # shuffle the dataset
                        shuffled_data = gan_data.shuffle(buffer_size=num_elements)
                        # take a single random element from the shuffled dataset
                        random_element = shuffled_data.take(1)
                        # iterate over the random_element dataset to access the value
                        for element in random_element:
                            # access the value of the random element as a tensor
                            real_sample = element
                        # reshape the real sample for compatibility with the first layer of the critic
                        real_sample = tf.reshape(real_sample, (1, self.window_length))
                    
                        ##################################################
                        #
                        # Get the state prepared by the encoding circuit
                        #
                        ##################################################
                        # generate noise parameters for the encoding layer
                        noise_values = np.random.uniform(0, 2 * np.pi, size=self.num_qubits)
                        generator_input_state = self.encoding_layer(noise_values)
                        # convert to tensorflow quantum tensor
                        generator_input = tfq.convert_to_tensor([generator_input_state])
                        # get the fake sample as the expectations of the quantum circuit
                        generated_sample = self.generator(generator_input)
                        generated_sample = tf.cast(generated_sample, dtype=tf.float64)
                        
                        # calculate the critic scores for real and fake samples
                        real_score = self.critic(real_sample)
                        fake_score = self.critic(generated_sample)
                     
                        # compute the gradient penalty
                        gradient_penalty = self.compute_gradient_penalty(real_sample, generated_sample)

                        # calculate the Wasserstein distance loss with gradient penalty
                        critic_loss = fake_score - real_score + self.gp * gradient_penalty
                        # accumulate the critic loss for the sample
                        critic_sum += critic_loss

                    # compute the gradients of critic and apply them
                    critic_gradients = critic_tape.gradient(critic_sum/self.batch_size, self.critic.trainable_variables)
                    self.c_optimizer.apply_gradients(zip(critic_gradients, self.critic.trainable_variables))
                    
                    # accumulate the average critic loss for all samples in this 't' iteration
                    critic_t_sum += critic_sum/self.batch_size
            
            # average critic loss for this epoch of WGAN training
            self.critic_loss_avg.append(critic_t_sum/self.n_critic)
            
            ################################################################
            #
            # Train generator for one iteration
            #
            ################################################################
            # sample a batch of input states using the encoding layer
            input_circuits_batch = []
            for _ in range(self.batch_size):
                noise_values = np.random.uniform(0, 2 * np.pi, size=self.num_qubits)
                input_circuits_batch.append(self.encoding_layer(noise_values))
            
            # convert to tensorflow quantum tensor
            generator_inputs = tfq.convert_to_tensor(input_circuits_batch)
                
            with tf.GradientTape() as gen_tape:
                # generate fake samples using the generator
                generated_samples = self.generator(generator_inputs)
                generated_samples = tf.cast(generated_samples, dtype=tf.float64)
                # calculate the critic scores for fake samples
                fake_scores = self.critic(generated_samples)
                # calculate the generator loss
                generator_loss = -tf.reduce_mean(fake_scores)

            # compute the gradients of generator and apply them
            generator_gradients = gen_tape.gradient(generator_loss, self.generator.trainable_variables)
            self.g_optimizer.apply_gradients(zip(generator_gradients, self.generator.trainable_variables))
            
            # average generator loss for this epoch
            self.generator_loss_avg.append(generator_loss)
            
            ########################################################################################################
            #
            # Calculate the stylized facts RMSEs and the EMD for real and fake data
            # 
            # Fake data has shape (num_samples x window_length), with num_samples = original_length / window_length
            # in order to get a time series close to the length of the original
            #
            ########################################################################################################
            # generate noise
            num_samples = len(original_data) // self.window_length
            input_circuits_batch = []
            for _ in range(num_samples):
                noise_values = np.random.uniform(0, 2 * np.pi, size=self.num_qubits)
                input_circuits_batch.append(self.encoding_layer(noise_values))
            
            # convert to tensorflow quantum tensor
            generator_inputs = tfq.convert_to_tensor(input_circuits_batch)
            # generate fake samples using the generator
            batch_generated = self.generator(generator_inputs)
            # concatenate all time series data into one
            generated_data = tf.reshape(batch_generated, shape=(num_samples*self.window_length,))
            generated_data = tf.cast(generated_data, dtype=tf.float64)
            # rescale
            generated_data = rescale(generated_data, preprocessed_data)
            # reverse the preprocessing on generated sample
            original_norm = lambert_w_transform(generated_data, 1)
            fake_original = denormalize(original_norm, tf.reduce_mean(original_data), tf.math.reduce_std(original_data))
            # calculate the temporal metrics for monitoring the training process
            corr_rmse, volatility_rmse, lev_rmse, emd = self.stylized_facts(original_data, fake_original)
            # store the EMD and RMSEs of stylized facts
            self.acf_avg.append(corr_rmse)
            self.vol_avg.append(volatility_rmse)
            self.lev_avg.append(lev_rmse)
            self.emd_avg.append(emd)
            
            # print progress every 100 epochs
            if epoch % 100 == 0 or epoch+1 == 3000:
                print(f'\nEpoch {epoch+1} completed')
                print(f'Critic loss (average): {self.critic_loss_avg[epoch][-1][0]}')
                print(f'Generator loss (average): {self.generator_loss_avg[epoch]}')
                print(f'\nEMD (average): {self.emd_avg[epoch]}')
                print(f'ACF RMSE (average): {self.acf_avg[epoch]}')
                print(f'VOLATILITY RMSE (average): {self.vol_avg[epoch]}')
                print(f'LEVERAGE RMSE (average): {self.lev_avg[epoch]}\n')
                print('Min-Max values of original log-returns: ', tf.reduce_min(original_data).numpy(), tf.reduce_max(original_data).numpy())
                print('Min-Max values of generated log-returns (for all batches): ', tf.reduce_min(fake_original).numpy(), tf.reduce_max(fake_original).numpy())
                print('Min-Max values after Lambert: ', tf.reduce_min(original_norm).numpy(), tf.reduce_max(original_norm).numpy())
                print()
    
    ###########################################################
    #
    # Sample a random number epsilon ~ U[0,1]
    # Create a convex combination of real and generated sample
    # Compute the gradient penalty for the critic network
    #
    ###########################################################
    def compute_gradient_penalty(self, real_sample, generated_sample):
        epsilon = tf.random.uniform((), dtype=tf.float64)
        interpolated_sample = epsilon * real_sample + (1 - epsilon) * generated_sample
    
        with tf.GradientTape() as tape:
            tape.watch(interpolated_sample)
            scores = self.critic(interpolated_sample)
            
        gradients = tape.gradient(scores, interpolated_sample)
        gradients_norm = tf.norm(gradients)
        gradient_penalty = (gradients_norm - 1)**2

        return gradient_penalty
    
    def stylized_facts(self, original_data, fake_original):
        """
        - Calculate the RMSEs of the stylized facts between the original S&P 500 log-returns and 
          generated time series
      
        - Evaluate the EMD between real and generated samples
        """
        
        ################################################
        #   
        # stylized facts for fake samples
        #
        ################################################
        # compute acf for maximum lags = 18
        acf_values = sm.tsa.acf(fake_original, nlags=18)
        # exclude zero lag
        acf_values_generated = tf.convert_to_tensor(acf_values[1:])
            
        # compute absolute acf (volatility clustering) for maximum lags = 18
        acf_abs_values = sm.tsa.acf(tf.abs(fake_original), nlags=18)
        # exclude zero lag
        acf_abs_values_generated = tf.convert_to_tensor(acf_abs_values[1:])
            
        # compute leverage effect for maximum lags = 18
        lev = []
        for lag in range(1, 19):
            # slice the tensors to get the appropriate lagged sequences
            r_t = fake_original[:-lag]
            squared_lag_r = tf.square(tf.abs(fake_original[lag:]))
                
            # calculate the leverage effect
            # calculate the correlation coefficient
            correlation_matrix = np.corrcoef(r_t, squared_lag_r)
            lev.append(correlation_matrix[0, 1])
            
        leverage_generated = tf.convert_to_tensor(lev)
        
        ################################################
        #   
        # stylized facts for real samples
        #
        ################################################
        
        # compute acf for maximum lags = 18
        acf_values = sm.tsa.acf(original_data, nlags=18)
        # exclude zero lag
        acf_values_original = tf.convert_to_tensor(acf_values[1:])
            
        # compute absolute acf (volatility clustering) for maximum lags = 18
        acf_abs_values = sm.tsa.acf(tf.abs(original_data), nlags=18)
        # exclude zero lag
        acf_abs_values_original = tf.convert_to_tensor(acf_abs_values[1:])
            
        # compute leverage effect for maximum lags = 18
        lev = []
        for lag in range(1, 19):
            # slice the tensors to get the appropriate lagged sequences
            r_t = original_data[:-lag]
            squared_lag_r = tf.square(tf.abs(original_data[lag:]))
                
            # calculate the leverage effect
            # calculate the correlation coefficient
            correlation_matrix = np.corrcoef(r_t, squared_lag_r)
            lev.append(correlation_matrix[0, 1])
            
        leverage_original = tf.convert_to_tensor(lev)
        
        # calculate average RMSEs of stylized facts
        # autocorrelations
        rmse_acf = tf.sqrt(tf.reduce_mean((acf_values_original-acf_values_generated)**2))
        # volatility clustering
        rmse_vol = tf.sqrt(tf.reduce_mean((acf_abs_values_original-acf_abs_values_generated)**2))
        # leverage effect
        rmse_lev = tf.sqrt(tf.reduce_mean((leverage_original-leverage_generated)**2))
        
        ####################################################################################
        #
        # compute the Earth's mover distance (EMD)
        #
        ####################################################################################
        bin_edges = np.linspace(-0.05, 0.05, num=50)  # define the bin edges
        bin_width = bin_edges[1] - bin_edges[0]
        bin_edges = np.append(bin_edges, bin_edges[-1] + bin_width)
        # compute the empirical distribution of original data
        empirical_real, _ = np.histogram(original_data, bins=bin_edges, density=True)
        empirical_real /= np.sum(empirical_real)
        # compute the empirical distribution of generated data
        empirical_fake, _ = np.histogram(fake_original, bins=bin_edges, density=True)
        empirical_fake /= np.sum(empirical_fake)
        
        # evaluate the EMD using SciPy
        emd = wasserstein_distance(empirical_real, empirical_fake)
 
        return rmse_acf, rmse_vol, rmse_lev, emd

# %%
##################################################################
#
# Hyperparameters
#
##################################################################
WINDOW_LENGTH = 20  # this must be equal to the number of Pauli strings to measure
NUM_QUBITS = 10  # number of qubits
NUM_LAYERS = 4  # number of layers for the PQC

# training hyperparameters
EPOCHS = 3000
BATCH_SIZE = 10

n_critic = 2 # number of iterations for the critic per epoch
LAMBDA = 10  # gradient penalty strength

# instantiate the QGAN model object
qgan = qGAN(EPOCHS, BATCH_SIZE, WINDOW_LENGTH, n_critic, LAMBDA, NUM_LAYERS, NUM_QUBITS)

# set the optimizers
c_optimizer = tf.keras.optimizers.Adam()
g_optimizer = tf.keras.optimizers.Adam()
qgan.compile_QGAN(c_optimizer, g_optimizer)

##################################################################################
#
# Data pre-processing
#
##################################################################################
# apply rolling window in transformed (scaled) log-returns with stride s=5
gan_data_tf = rolling_window(scaled_data, WINDOW_LENGTH, 5)
# create TensorFlow datasets
gan_data = tf.data.Dataset.from_tensor_slices(gan_data_tf)
# get the number of elements in the dataset
num_elements = gan_data.cardinality().numpy()

# %%
# display the generator circuit
SVGCircuit(qgan.define_generator_circuit())
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.

# %%
# train the QGAN
print('Training started...')
print('Number of samples to process per epoch: ', num_elements)
print()
start_time_train = time.time()
qgan.train_qgan(gan_data, sp500_log_r_tf, transformed_sp500, num_elements)
exec_time_train = time.time() - start_time_train
print(f'\nQGAN training completed. Training time: --- {exec_time_train/3600:.02f} hours ---')
# Out:
# Training started...
# Number of samples to process per epoch:  752
#
# Processing epoch 1/3000
#
# Epoch 1 completed
# Critic loss (average): 8.294159919543263
# Generator loss (average): -0.004605736557593077
#
# EMD (average): 0.025871436369218875
# ACF RMSE (average): 0.05051613396693876
# VOLATILITY RMSE (average): 0.31968612890567677
# LEVERAGE RMSE (average): 0.09406657964015294
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.009458992362728479 0.004348972277956112
# Min-Max values after Lambert:  -0.7361920914610882 0.30990219499577254
#
# Processing epoch 2/3000
# Processing epoch 3/3000
# Processing epoch 4/3000
# Processing epoch 5/3000
# Processing epoch 6/3000
# Processing epoch 7/3000
# Processing epoch 8/3000
# Processing epoch 9/3000
# Processing epoch 10/3000
# Processing epoch 11/3000
# Processing epoch 12/3000
# Processing epoch 13/3000
# Processing epoch 14/3000
# Processing epoch 15/3000
# Processing epoch 16/3000
# Processing epoch 17/3000
# Processing epoch 18/3000
# Processing epoch 19/3000
# Processing epoch 20/3000
# Processing epoch 21/3000
# Processing epoch 22/3000
# Processing epoch 23/3000
# Processing epoch 24/3000
# Processing epoch 25/3000
# Processing epoch 26/3000
# Processing epoch 27/3000
# Processing epoch 28/3000
# Processing epoch 29/3000
# Processing epoch 30/3000
# Processing epoch 31/3000
# Processing epoch 32/3000
# Processing epoch 33/3000
# Processing epoch 34/3000
# Processing epoch 35/3000
# Processing epoch 36/3000
# Processing epoch 37/3000
# Processing epoch 38/3000
# Processing epoch 39/3000
# Processing epoch 40/3000
# Processing epoch 41/3000
# Processing epoch 42/3000
# Processing epoch 43/3000
# Processing epoch 44/3000
# Processing epoch 45/3000
# Processing epoch 46/3000
# Processing epoch 47/3000
# Processing epoch 48/3000
# Processing epoch 49/3000
# Processing epoch 50/3000
# Processing epoch 51/3000
# Processing epoch 52/3000
# Processing epoch 53/3000
# Processing epoch 54/3000
# Processing epoch 55/3000
# Processing epoch 56/3000
# Processing epoch 57/3000
# Processing epoch 58/3000
# Processing epoch 59/3000
# Processing epoch 60/3000
# Processing epoch 61/3000
# Processing epoch 62/3000
# Processing epoch 63/3000
# Processing epoch 64/3000
# Processing epoch 65/3000
# Processing epoch 66/3000
# Processing epoch 67/3000
# Processing epoch 68/3000
# Processing epoch 69/3000
# Processing epoch 70/3000
# Processing epoch 71/3000
# Processing epoch 72/3000
# Processing epoch 73/3000
# Processing epoch 74/3000
# Processing epoch 75/3000
# Processing epoch 76/3000
# Processing epoch 77/3000
# Processing epoch 78/3000
# Processing epoch 79/3000
# Processing epoch 80/3000
# Processing epoch 81/3000
# Processing epoch 82/3000
# Processing epoch 83/3000
# Processing epoch 84/3000
# Processing epoch 85/3000
# Processing epoch 86/3000
# Processing epoch 87/3000
# Processing epoch 88/3000
# Processing epoch 89/3000
# Processing epoch 90/3000
# Processing epoch 91/3000
# Processing epoch 92/3000
# Processing epoch 93/3000
# Processing epoch 94/3000
# Processing epoch 95/3000
# Processing epoch 96/3000
# Processing epoch 97/3000
# Processing epoch 98/3000
# Processing epoch 99/3000
# Processing epoch 100/3000
# Processing epoch 101/3000
#
# Epoch 101 completed
# Critic loss (average): -0.9353904690517436
# Generator loss (average): -0.48890682282964537
#
# EMD (average): 0.02488207466709122
# ACF RMSE (average): 0.05964970695918394
# VOLATILITY RMSE (average): 0.32481207336003326
# LEVERAGE RMSE (average): 0.08781225897269594
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.007214354892441745 0.0051758926751409385
# Min-Max values after Lambert:  -0.566137887678197 0.37254985707776334
#
# Processing epoch 102/3000
# Processing epoch 103/3000
# Processing epoch 104/3000
# Processing epoch 105/3000
# Processing epoch 106/3000
# Processing epoch 107/3000
# Processing epoch 108/3000
# Processing epoch 109/3000
# Processing epoch 110/3000
# Processing epoch 111/3000
# Processing epoch 112/3000
# Processing epoch 113/3000
# Processing epoch 114/3000
# Processing epoch 115/3000
# Processing epoch 116/3000
# Processing epoch 117/3000
# Processing epoch 118/3000
# Processing epoch 119/3000
# Processing epoch 120/3000
# Processing epoch 121/3000
# Processing epoch 122/3000
# Processing epoch 123/3000
# Processing epoch 124/3000
# Processing epoch 125/3000
# Processing epoch 126/3000
# Processing epoch 127/3000
# Processing epoch 128/3000
# Processing epoch 129/3000
# Processing epoch 130/3000
# Processing epoch 131/3000
# Processing epoch 132/3000
# Processing epoch 133/3000
# Processing epoch 134/3000
# Processing epoch 135/3000
# Processing epoch 136/3000
# Processing epoch 137/3000
# Processing epoch 138/3000
# Processing epoch 139/3000
# Processing epoch 140/3000
# Processing epoch 141/3000
# Processing epoch 142/3000
# Processing epoch 143/3000
# Processing epoch 144/3000
# Processing epoch 145/3000
# Processing epoch 146/3000
# Processing epoch 147/3000
# Processing epoch 148/3000
# Processing epoch 149/3000
# Processing epoch 150/3000
# Processing epoch 151/3000
# Processing epoch 152/3000
# Processing epoch 153/3000
# Processing epoch 154/3000
# Processing epoch 155/3000
# Processing epoch 156/3000
# Processing epoch 157/3000
# Processing epoch 158/3000
# Processing epoch 159/3000
# Processing epoch 160/3000
# Processing epoch 161/3000
# Processing epoch 162/3000
# Processing epoch 163/3000
# Processing epoch 164/3000
# Processing epoch 165/3000
# Processing epoch 166/3000
# Processing epoch 167/3000
# Processing epoch 168/3000
# Processing epoch 169/3000
# Processing epoch 170/3000
# Processing epoch 171/3000
# Processing epoch 172/3000
# Processing epoch 173/3000
# Processing epoch 174/3000
# Processing epoch 175/3000
# Processing epoch 176/3000
# Processing epoch 177/3000
# Processing epoch 178/3000
# Processing epoch 179/3000
# Processing epoch 180/3000
# Processing epoch 181/3000
# Processing epoch 182/3000
# Processing epoch 183/3000
# Processing epoch 184/3000
# Processing epoch 185/3000
# Processing epoch 186/3000
# Processing epoch 187/3000
# Processing epoch 188/3000
# Processing epoch 189/3000
# Processing epoch 190/3000
# Processing epoch 191/3000
# Processing epoch 192/3000
# Processing epoch 193/3000
# Processing epoch 194/3000
# Processing epoch 195/3000
# Processing epoch 196/3000
# Processing epoch 197/3000
# Processing epoch 198/3000
# Processing epoch 199/3000
# Processing epoch 200/3000
# Processing epoch 201/3000
#
# Epoch 201 completed
# Critic loss (average): -0.846895850433808
# Generator loss (average): -0.676684120923073
#
# EMD (average): 0.021796968284112504
# ACF RMSE (average): 0.048964748289693834
# VOLATILITY RMSE (average): 0.3481474677895257
# LEVERAGE RMSE (average): 0.08073879137149248
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.009775796514929663 0.007755904639176039
# Min-Max values after Lambert:  -0.7601932402304725 0.5680121025860666
#
# Processing epoch 202/3000
# Processing epoch 203/3000
# Processing epoch 204/3000
# Processing epoch 205/3000
# Processing epoch 206/3000
# Processing epoch 207/3000
# Processing epoch 208/3000
# Processing epoch 209/3000
# Processing epoch 210/3000
# Processing epoch 211/3000
# Processing epoch 212/3000
# Processing epoch 213/3000
# Processing epoch 214/3000
# Processing epoch 215/3000
# Processing epoch 216/3000
# Processing epoch 217/3000
# Processing epoch 218/3000
# Processing epoch 219/3000
# Processing epoch 220/3000
# Processing epoch 221/3000
# Processing epoch 222/3000
# Processing epoch 223/3000
# Processing epoch 224/3000
# Processing epoch 225/3000
# Processing epoch 226/3000
# Processing epoch 227/3000
# Processing epoch 228/3000
# Processing epoch 229/3000
# Processing epoch 230/3000
# Processing epoch 231/3000
# Processing epoch 232/3000
# Processing epoch 233/3000
# Processing epoch 234/3000
# Processing epoch 235/3000
# Processing epoch 236/3000
# Processing epoch 237/3000
# Processing epoch 238/3000
# Processing epoch 239/3000
# Processing epoch 240/3000
# Processing epoch 241/3000
# Processing epoch 242/3000
# Processing epoch 243/3000
# Processing epoch 244/3000
# Processing epoch 245/3000
# Processing epoch 246/3000
# Processing epoch 247/3000
# Processing epoch 248/3000
# Processing epoch 249/3000
# Processing epoch 250/3000
# Processing epoch 251/3000
# Processing epoch 252/3000
# Processing epoch 253/3000
# Processing epoch 254/3000
# Processing epoch 255/3000
# Processing epoch 256/3000
# Processing epoch 257/3000
# Processing epoch 258/3000
# Processing epoch 259/3000
# Processing epoch 260/3000
# Processing epoch 261/3000
# Processing epoch 262/3000
# Processing epoch 263/3000
# Processing epoch 264/3000
# Processing epoch 265/3000
# Processing epoch 266/3000
# Processing epoch 267/3000
# Processing epoch 268/3000
# Processing epoch 269/3000
# Processing epoch 270/3000
# Processing epoch 271/3000
# Processing epoch 272/3000
# Processing epoch 273/3000
# Processing epoch 274/3000
# Processing epoch 275/3000
# Processing epoch 276/3000
# Processing epoch 277/3000
# Processing epoch 278/3000
# Processing epoch 279/3000
# Processing epoch 280/3000
# Processing epoch 281/3000
# Processing epoch 282/3000
# Processing epoch 283/3000
# Processing epoch 284/3000
# Processing epoch 285/3000
# Processing epoch 286/3000
# Processing epoch 287/3000
# Processing epoch 288/3000
# Processing epoch 289/3000
# Processing epoch 290/3000
# Processing epoch 291/3000
# Processing epoch 292/3000
# Processing epoch 293/3000
# Processing epoch 294/3000
# Processing epoch 295/3000
# Processing epoch 296/3000
# Processing epoch 297/3000
# Processing epoch 298/3000
# Processing epoch 299/3000
# Processing epoch 300/3000
# Processing epoch 301/3000
#
# Epoch 301 completed
# Critic loss (average): -0.8417107550212634
# Generator loss (average): -0.8869688002482572
#
# EMD (average): 0.016988457645814633
# ACF RMSE (average): 0.05140835488291371
# VOLATILITY RMSE (average): 0.35838967152615014
# LEVERAGE RMSE (average): 0.09009078300159593
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.012489674441387287 0.011490305245652598
# Min-Max values after Lambert:  -0.9657971990242111 0.8509310728639684
#
# Processing epoch 302/3000
# Processing epoch 303/3000
# Processing epoch 304/3000
# Processing epoch 305/3000
# Processing epoch 306/3000
# Processing epoch 307/3000
# Processing epoch 308/3000
# Processing epoch 309/3000
# Processing epoch 310/3000
# Processing epoch 311/3000
# Processing epoch 312/3000
# Processing epoch 313/3000
# Processing epoch 314/3000
# Processing epoch 315/3000
# Processing epoch 316/3000
# Processing epoch 317/3000
# Processing epoch 318/3000
# Processing epoch 319/3000
# Processing epoch 320/3000
# Processing epoch 321/3000
# Processing epoch 322/3000
# Processing epoch 323/3000
# Processing epoch 324/3000
# Processing epoch 325/3000
# Processing epoch 326/3000
# Processing epoch 327/3000
# Processing epoch 328/3000
# Processing epoch 329/3000
# Processing epoch 330/3000
# Processing epoch 331/3000
# Processing epoch 332/3000
# Processing epoch 333/3000
# Processing epoch 334/3000
# Processing epoch 335/3000
# Processing epoch 336/3000
# Processing epoch 337/3000
# Processing epoch 338/3000
# Processing epoch 339/3000
# Processing epoch 340/3000
# Processing epoch 341/3000
# Processing epoch 342/3000
# Processing epoch 343/3000
# Processing epoch 344/3000
# Processing epoch 345/3000
# Processing epoch 346/3000
# Processing epoch 347/3000
# Processing epoch 348/3000
# Processing epoch 349/3000
# Processing epoch 350/3000
# Processing epoch 351/3000
# Processing epoch 352/3000
# Processing epoch 353/3000
# Processing epoch 354/3000
# Processing epoch 355/3000
# Processing epoch 356/3000
# Processing epoch 357/3000
# Processing epoch 358/3000
# Processing epoch 359/3000
# Processing epoch 360/3000
# Processing epoch 361/3000
# Processing epoch 362/3000
# Processing epoch 363/3000
# Processing epoch 364/3000
# Processing epoch 365/3000
# Processing epoch 366/3000
# Processing epoch 367/3000
# Processing epoch 368/3000
# Processing epoch 369/3000
# Processing epoch 370/3000
# Processing epoch 371/3000
# Processing epoch 372/3000
# Processing epoch 373/3000
# Processing epoch 374/3000
# Processing epoch 375/3000
# Processing epoch 376/3000
# Processing epoch 377/3000
# Processing epoch 378/3000
# Processing epoch 379/3000
# Processing epoch 380/3000
# Processing epoch 381/3000
# Processing epoch 382/3000
# Processing epoch 383/3000
# Processing epoch 384/3000
# Processing epoch 385/3000
# Processing epoch 386/3000
# Processing epoch 387/3000
# Processing epoch 388/3000
# Processing epoch 389/3000
# Processing epoch 390/3000
# Processing epoch 391/3000
# Processing epoch 392/3000
# Processing epoch 393/3000
# Processing epoch 394/3000
# Processing epoch 395/3000
# Processing epoch 396/3000
# Processing epoch 397/3000
# Processing epoch 398/3000
# Processing epoch 399/3000
# Processing epoch 400/3000
# Processing epoch 401/3000
#
# Epoch 401 completed
# Critic loss (average): -0.7211345615263212
# Generator loss (average): -0.9785528946546922
#
# EMD (average): 0.013181772177809107
# ACF RMSE (average): 0.04952923830066535
# VOLATILITY RMSE (average): 0.3471884706161332
# LEVERAGE RMSE (average): 0.08698207792883822
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.01760323220936359 0.017657971332867207
# Min-Max values after Lambert:  -1.3532014040426483 1.3181947444118023
#
# Processing epoch 402/3000
# Processing epoch 403/3000
# Processing epoch 404/3000
# Processing epoch 405/3000
# Processing epoch 406/3000
# Processing epoch 407/3000
# Processing epoch 408/3000
# Processing epoch 409/3000
# Processing epoch 410/3000
# Processing epoch 411/3000
# Processing epoch 412/3000
# Processing epoch 413/3000
# Processing epoch 414/3000
# Processing epoch 415/3000
# Processing epoch 416/3000
# Processing epoch 417/3000
# Processing epoch 418/3000
# Processing epoch 419/3000
# Processing epoch 420/3000
# Processing epoch 421/3000
# Processing epoch 422/3000
# Processing epoch 423/3000
# Processing epoch 424/3000
# Processing epoch 425/3000
# Processing epoch 426/3000
# Processing epoch 427/3000
# Processing epoch 428/3000
# Processing epoch 429/3000
# Processing epoch 430/3000
# Processing epoch 431/3000
# Processing epoch 432/3000
# Processing epoch 433/3000
# Processing epoch 434/3000
# Processing epoch 435/3000
# Processing epoch 436/3000
# Processing epoch 437/3000
# Processing epoch 438/3000
# Processing epoch 439/3000
# Processing epoch 440/3000
# Processing epoch 441/3000
# Processing epoch 442/3000
# Processing epoch 443/3000
# Processing epoch 444/3000
# Processing epoch 445/3000
# Processing epoch 446/3000
# Processing epoch 447/3000
# Processing epoch 448/3000
# Processing epoch 449/3000
# Processing epoch 450/3000
# Processing epoch 451/3000
# Processing epoch 452/3000
# Processing epoch 453/3000
# Processing epoch 454/3000
# Processing epoch 455/3000
# Processing epoch 456/3000
# Processing epoch 457/3000
# Processing epoch 458/3000
# Processing epoch 459/3000
# Processing epoch 460/3000
# Processing epoch 461/3000
# Processing epoch 462/3000
# Processing epoch 463/3000
# Processing epoch 464/3000
# Processing epoch 465/3000
# Processing epoch 466/3000
# Processing epoch 467/3000
# Processing epoch 468/3000
# Processing epoch 469/3000
# Processing epoch 470/3000
# Processing epoch 471/3000
# Processing epoch 472/3000
# Processing epoch 473/3000
# Processing epoch 474/3000
# Processing epoch 475/3000
# Processing epoch 476/3000
# Processing epoch 477/3000
# Processing epoch 478/3000
# Processing epoch 479/3000
# Processing epoch 480/3000
# Processing epoch 481/3000
# Processing epoch 482/3000
# Processing epoch 483/3000
# Processing epoch 484/3000
# Processing epoch 485/3000
# Processing epoch 486/3000
# Processing epoch 487/3000
# Processing epoch 488/3000
# Processing epoch 489/3000
# Processing epoch 490/3000
# Processing epoch 491/3000
# Processing epoch 492/3000
# Processing epoch 493/3000
# Processing epoch 494/3000
# Processing epoch 495/3000
# Processing epoch 496/3000
# Processing epoch 497/3000
# Processing epoch 498/3000
# Processing epoch 499/3000
# Processing epoch 500/3000
# Processing epoch 501/3000
#
# Epoch 501 completed
# Critic loss (average): -0.6847640058557344
# Generator loss (average): -1.6395356901609635
#
# EMD (average): 0.009131730670821158
# ACF RMSE (average): 0.0519013026034653
# VOLATILITY RMSE (average): 0.34270325393927875
# LEVERAGE RMSE (average): 0.0811731408698572
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.016357546295412955 0.014976852924257843
# Min-Max values after Lambert:  -1.2588279789062595 1.1150726535355966
#
# Processing epoch 502/3000
# Processing epoch 503/3000
# Processing epoch 504/3000
# Processing epoch 505/3000
# Processing epoch 506/3000
# Processing epoch 507/3000
# Processing epoch 508/3000
# Processing epoch 509/3000
# Processing epoch 510/3000
# Processing epoch 511/3000
# Processing epoch 512/3000
# Processing epoch 513/3000
# Processing epoch 514/3000
# Processing epoch 515/3000
# Processing epoch 516/3000
# Processing epoch 517/3000
# Processing epoch 518/3000
# Processing epoch 519/3000
# Processing epoch 520/3000
# Processing epoch 521/3000
# Processing epoch 522/3000
# Processing epoch 523/3000
# Processing epoch 524/3000
# Processing epoch 525/3000
# Processing epoch 526/3000
# Processing epoch 527/3000
# Processing epoch 528/3000
# Processing epoch 529/3000
# Processing epoch 530/3000
# Processing epoch 531/3000
# Processing epoch 532/3000
# Processing epoch 533/3000
# Processing epoch 534/3000
# Processing epoch 535/3000
# Processing epoch 536/3000
# Processing epoch 537/3000
# Processing epoch 538/3000
# Processing epoch 539/3000
# Processing epoch 540/3000
# Processing epoch 541/3000
# Processing epoch 542/3000
# Processing epoch 543/3000
# Processing epoch 544/3000
# Processing epoch 545/3000
# Processing epoch 546/3000
# Processing epoch 547/3000
# Processing epoch 548/3000
# Processing epoch 549/3000
# Processing epoch 550/3000
# Processing epoch 551/3000
# Processing epoch 552/3000
# Processing epoch 553/3000
# Processing epoch 554/3000
# Processing epoch 555/3000
# Processing epoch 556/3000
# Processing epoch 557/3000
# Processing epoch 558/3000
# Processing epoch 559/3000
# Processing epoch 560/3000
# Processing epoch 561/3000
# Processing epoch 562/3000
# Processing epoch 563/3000
# Processing epoch 564/3000
# Processing epoch 565/3000
# Processing epoch 566/3000
# Processing epoch 567/3000
# Processing epoch 568/3000
# Processing epoch 569/3000
# Processing epoch 570/3000
# Processing epoch 571/3000
# Processing epoch 572/3000
# Processing epoch 573/3000
# Processing epoch 574/3000
# Processing epoch 575/3000
# Processing epoch 576/3000
# Processing epoch 577/3000
# Processing epoch 578/3000
# Processing epoch 579/3000
# Processing epoch 580/3000
# Processing epoch 581/3000
# Processing epoch 582/3000
# Processing epoch 583/3000
# Processing epoch 584/3000
# Processing epoch 585/3000
# Processing epoch 586/3000
# Processing epoch 587/3000
# Processing epoch 588/3000
# Processing epoch 589/3000
# Processing epoch 590/3000
# Processing epoch 591/3000
# Processing epoch 592/3000
# Processing epoch 593/3000
# Processing epoch 594/3000
# Processing epoch 595/3000
# Processing epoch 596/3000
# Processing epoch 597/3000
# Processing epoch 598/3000
# Processing epoch 599/3000
# Processing epoch 600/3000
# Processing epoch 601/3000
#
# Epoch 601 completed
# Critic loss (average): -0.5543211452704697
# Generator loss (average): -1.0404368074759613
#
# EMD (average): 0.007565694758747739
# ACF RMSE (average): 0.055211636168247626
# VOLATILITY RMSE (average): 0.334952384834884
# LEVERAGE RMSE (average): 0.08678323426095957
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.019496278043149906 0.018167604546707957
# Min-Max values after Lambert:  -1.4966189519765376 1.3568046631840902
#
# Processing epoch 602/3000
# Processing epoch 603/3000
# Processing epoch 604/3000
# Processing epoch 605/3000
# Processing epoch 606/3000
# Processing epoch 607/3000
# Processing epoch 608/3000
# Processing epoch 609/3000
# Processing epoch 610/3000
# Processing epoch 611/3000
# Processing epoch 612/3000
# Processing epoch 613/3000
# Processing epoch 614/3000
# Processing epoch 615/3000
# Processing epoch 616/3000
# Processing epoch 617/3000
# Processing epoch 618/3000
# Processing epoch 619/3000
# Processing epoch 620/3000
# Processing epoch 621/3000
# Processing epoch 622/3000
# Processing epoch 623/3000
# Processing epoch 624/3000
# Processing epoch 625/3000
# Processing epoch 626/3000
# Processing epoch 627/3000
# Processing epoch 628/3000
# Processing epoch 629/3000
# Processing epoch 630/3000
# Processing epoch 631/3000
# Processing epoch 632/3000
# Processing epoch 633/3000
# Processing epoch 634/3000
# Processing epoch 635/3000
# Processing epoch 636/3000
# Processing epoch 637/3000
# Processing epoch 638/3000
# Processing epoch 639/3000
# Processing epoch 640/3000
# Processing epoch 641/3000
# Processing epoch 642/3000
# Processing epoch 643/3000
# Processing epoch 644/3000
# Processing epoch 645/3000
# Processing epoch 646/3000
# Processing epoch 647/3000
# Processing epoch 648/3000
# Processing epoch 649/3000
# Processing epoch 650/3000
# Processing epoch 651/3000
# Processing epoch 652/3000
# Processing epoch 653/3000
# Processing epoch 654/3000
# Processing epoch 655/3000
# Processing epoch 656/3000
# Processing epoch 657/3000
# Processing epoch 658/3000
# Processing epoch 659/3000
# Processing epoch 660/3000
# Processing epoch 661/3000
# Processing epoch 662/3000
# Processing epoch 663/3000
# Processing epoch 664/3000
# Processing epoch 665/3000
# Processing epoch 666/3000
# Processing epoch 667/3000
# Processing epoch 668/3000
# Processing epoch 669/3000
# Processing epoch 670/3000
# Processing epoch 671/3000
# Processing epoch 672/3000
# Processing epoch 673/3000
# Processing epoch 674/3000
# Processing epoch 675/3000
# Processing epoch 676/3000
# Processing epoch 677/3000
# Processing epoch 678/3000
# Processing epoch 679/3000
# Processing epoch 680/3000
# Processing epoch 681/3000
# Processing epoch 682/3000
# Processing epoch 683/3000
# Processing epoch 684/3000
# Processing epoch 685/3000
# Processing epoch 686/3000
# Processing epoch 687/3000
# Processing epoch 688/3000
# Processing epoch 689/3000
# Processing epoch 690/3000
# Processing epoch 691/3000
# Processing epoch 692/3000
# Processing epoch 693/3000
# Processing epoch 694/3000
# Processing epoch 695/3000
# Processing epoch 696/3000
# Processing epoch 697/3000
# Processing epoch 698/3000
# Processing epoch 699/3000
# Processing epoch 700/3000
# Processing epoch 701/3000
#
# Epoch 701 completed
# Critic loss (average): -0.3140699480685496
# Generator loss (average): -0.8909919668844568
#
# EMD (average): 0.006920118948792886
# ACF RMSE (average): 0.04803400202612706
# VOLATILITY RMSE (average): 0.33498439054448975
# LEVERAGE RMSE (average): 0.09138143448112081
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.02664512510237285 0.022475267820981564
# Min-Max values after Lambert:  -2.038217098988904 1.6831541329618647
#
# Processing epoch 702/3000
# Processing epoch 703/3000
# Processing epoch 704/3000
# Processing epoch 705/3000
# Processing epoch 706/3000
# Processing epoch 707/3000
# Processing epoch 708/3000
# Processing epoch 709/3000
# Processing epoch 710/3000
# Processing epoch 711/3000
# Processing epoch 712/3000
# Processing epoch 713/3000
# Processing epoch 714/3000
# Processing epoch 715/3000
# Processing epoch 716/3000
# Processing epoch 717/3000
# Processing epoch 718/3000
# Processing epoch 719/3000
# Processing epoch 720/3000
# Processing epoch 721/3000
# Processing epoch 722/3000
# Processing epoch 723/3000
# Processing epoch 724/3000
# Processing epoch 725/3000
# Processing epoch 726/3000
# Processing epoch 727/3000
# Processing epoch 728/3000
# Processing epoch 729/3000
# Processing epoch 730/3000
# Processing epoch 731/3000
# Processing epoch 732/3000
# Processing epoch 733/3000
# Processing epoch 734/3000
# Processing epoch 735/3000
# Processing epoch 736/3000
# Processing epoch 737/3000
# Processing epoch 738/3000
# Processing epoch 739/3000
# Processing epoch 740/3000
# Processing epoch 741/3000
# Processing epoch 742/3000
# Processing epoch 743/3000
# Processing epoch 744/3000
# Processing epoch 745/3000
# Processing epoch 746/3000
# Processing epoch 747/3000
# Processing epoch 748/3000
# Processing epoch 749/3000
# Processing epoch 750/3000
# Processing epoch 751/3000
# Processing epoch 752/3000
# Processing epoch 753/3000
# Processing epoch 754/3000
# Processing epoch 755/3000
# Processing epoch 756/3000
# Processing epoch 757/3000
# Processing epoch 758/3000
# Processing epoch 759/3000
# Processing epoch 760/3000
# Processing epoch 761/3000
# Processing epoch 762/3000
# Processing epoch 763/3000
# Processing epoch 764/3000
# Processing epoch 765/3000
# Processing epoch 766/3000
# Processing epoch 767/3000
# Processing epoch 768/3000
# Processing epoch 769/3000
# Processing epoch 770/3000
# Processing epoch 771/3000
# Processing epoch 772/3000
# Processing epoch 773/3000
# Processing epoch 774/3000
# Processing epoch 775/3000
# Processing epoch 776/3000
# Processing epoch 777/3000
# Processing epoch 778/3000
# Processing epoch 779/3000
# Processing epoch 780/3000
# Processing epoch 781/3000
# Processing epoch 782/3000
# Processing epoch 783/3000
# Processing epoch 784/3000
# Processing epoch 785/3000
# Processing epoch 786/3000
# Processing epoch 787/3000
# Processing epoch 788/3000
# Processing epoch 789/3000
# Processing epoch 790/3000
# Processing epoch 791/3000
# Processing epoch 792/3000
# Processing epoch 793/3000
# Processing epoch 794/3000
# Processing epoch 795/3000
# Processing epoch 796/3000
# Processing epoch 797/3000
# Processing epoch 798/3000
# Processing epoch 799/3000
# Processing epoch 800/3000
# Processing epoch 801/3000
#
# Epoch 801 completed
# Critic loss (average): -0.34516190643241
# Generator loss (average): -0.2613115101574245
#
# EMD (average): 0.007831942185883086
# ACF RMSE (average): 0.0492982226961522
# VOLATILITY RMSE (average): 0.33460432168515053
# LEVERAGE RMSE (average): 0.08582263254485926
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.02664512510237285 0.021387172187739285
# Min-Max values after Lambert:  -2.038217098988904 1.600719780421621
#
# Processing epoch 802/3000
# Processing epoch 803/3000
# Processing epoch 804/3000
# Processing epoch 805/3000
# Processing epoch 806/3000
# Processing epoch 807/3000
# Processing epoch 808/3000
# Processing epoch 809/3000
# Processing epoch 810/3000
# Processing epoch 811/3000
# Processing epoch 812/3000
# Processing epoch 813/3000
# Processing epoch 814/3000
# Processing epoch 815/3000
# Processing epoch 816/3000
# Processing epoch 817/3000
# Processing epoch 818/3000
# Processing epoch 819/3000
# Processing epoch 820/3000
# Processing epoch 821/3000
# Processing epoch 822/3000
# Processing epoch 823/3000
# Processing epoch 824/3000
# Processing epoch 825/3000
# Processing epoch 826/3000
# Processing epoch 827/3000
# Processing epoch 828/3000
# Processing epoch 829/3000
# Processing epoch 830/3000
# Processing epoch 831/3000
# Processing epoch 832/3000
# Processing epoch 833/3000
# Processing epoch 834/3000
# Processing epoch 835/3000
# Processing epoch 836/3000
# Processing epoch 837/3000
# Processing epoch 838/3000
# Processing epoch 839/3000
# Processing epoch 840/3000
# Processing epoch 841/3000
# Processing epoch 842/3000
# Processing epoch 843/3000
# Processing epoch 844/3000
# Processing epoch 845/3000
# Processing epoch 846/3000
# Processing epoch 847/3000
# Processing epoch 848/3000
# Processing epoch 849/3000
# Processing epoch 850/3000
# Processing epoch 851/3000
# Processing epoch 852/3000
# Processing epoch 853/3000
# Processing epoch 854/3000
# Processing epoch 855/3000
# Processing epoch 856/3000
# Processing epoch 857/3000
# Processing epoch 858/3000
# Processing epoch 859/3000
# Processing epoch 860/3000
# Processing epoch 861/3000
# Processing epoch 862/3000
# Processing epoch 863/3000
# Processing epoch 864/3000
# Processing epoch 865/3000
# Processing epoch 866/3000
# Processing epoch 867/3000
# Processing epoch 868/3000
# Processing epoch 869/3000
# Processing epoch 870/3000
# Processing epoch 871/3000
# Processing epoch 872/3000
# Processing epoch 873/3000
# Processing epoch 874/3000
# Processing epoch 875/3000
# Processing epoch 876/3000
# Processing epoch 877/3000
# Processing epoch 878/3000
# Processing epoch 879/3000
# Processing epoch 880/3000
# Processing epoch 881/3000
# Processing epoch 882/3000
# Processing epoch 883/3000
# Processing epoch 884/3000
# Processing epoch 885/3000
# Processing epoch 886/3000
# Processing epoch 887/3000
# Processing epoch 888/3000
# Processing epoch 889/3000
# Processing epoch 890/3000
# Processing epoch 891/3000
# Processing epoch 892/3000
# Processing epoch 893/3000
# Processing epoch 894/3000
# Processing epoch 895/3000
# Processing epoch 896/3000
# Processing epoch 897/3000
# Processing epoch 898/3000
# Processing epoch 899/3000
# Processing epoch 900/3000
# Processing epoch 901/3000
#
# Epoch 901 completed
# Critic loss (average): -0.32602830125881554
# Generator loss (average): -0.05843829020129613
#
# EMD (average): 0.005739717070175252
# ACF RMSE (average): 0.0490609720599045
# VOLATILITY RMSE (average): 0.3296025306111898
# LEVERAGE RMSE (average): 0.08613337784840554
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.022544871419954513 0.02684745641624966
# Min-Max values after Lambert:  -1.7275810232298874 2.014392054541235
#
# Processing epoch 902/3000
# Processing epoch 903/3000
# Processing epoch 904/3000
# Processing epoch 905/3000
# Processing epoch 906/3000
# Processing epoch 907/3000
# Processing epoch 908/3000
# Processing epoch 909/3000
# Processing epoch 910/3000
# Processing epoch 911/3000
# Processing epoch 912/3000
# Processing epoch 913/3000
# Processing epoch 914/3000
# Processing epoch 915/3000
# Processing epoch 916/3000
# Processing epoch 917/3000
# Processing epoch 918/3000
# Processing epoch 919/3000
# Processing epoch 920/3000
# Processing epoch 921/3000
# Processing epoch 922/3000
# Processing epoch 923/3000
# Processing epoch 924/3000
# Processing epoch 925/3000
# Processing epoch 926/3000
# Processing epoch 927/3000
# Processing epoch 928/3000
# Processing epoch 929/3000
# Processing epoch 930/3000
# Processing epoch 931/3000
# Processing epoch 932/3000
# Processing epoch 933/3000
# Processing epoch 934/3000
# Processing epoch 935/3000
# Processing epoch 936/3000
# Processing epoch 937/3000
# Processing epoch 938/3000
# Processing epoch 939/3000
# Processing epoch 940/3000
# Processing epoch 941/3000
# Processing epoch 942/3000
# Processing epoch 943/3000
# Processing epoch 944/3000
# Processing epoch 945/3000
# Processing epoch 946/3000
# Processing epoch 947/3000
# Processing epoch 948/3000
# Processing epoch 949/3000
# Processing epoch 950/3000
# Processing epoch 951/3000
# Processing epoch 952/3000
# Processing epoch 953/3000
# Processing epoch 954/3000
# Processing epoch 955/3000
# Processing epoch 956/3000
# Processing epoch 957/3000
# Processing epoch 958/3000
# Processing epoch 959/3000
# Processing epoch 960/3000
# Processing epoch 961/3000
# Processing epoch 962/3000
# Processing epoch 963/3000
# Processing epoch 964/3000
# Processing epoch 965/3000
# Processing epoch 966/3000
# Processing epoch 967/3000
# Processing epoch 968/3000
# Processing epoch 969/3000
# Processing epoch 970/3000
# Processing epoch 971/3000
# Processing epoch 972/3000
# Processing epoch 973/3000
# Processing epoch 974/3000
# Processing epoch 975/3000
# Processing epoch 976/3000
# Processing epoch 977/3000
# Processing epoch 978/3000
# Processing epoch 979/3000
# Processing epoch 980/3000
# Processing epoch 981/3000
# Processing epoch 982/3000
# Processing epoch 983/3000
# Processing epoch 984/3000
# Processing epoch 985/3000
# Processing epoch 986/3000
# Processing epoch 987/3000
# Processing epoch 988/3000
# Processing epoch 989/3000
# Processing epoch 990/3000
# Processing epoch 991/3000
# Processing epoch 992/3000
# Processing epoch 993/3000
# Processing epoch 994/3000
# Processing epoch 995/3000
# Processing epoch 996/3000
# Processing epoch 997/3000
# Processing epoch 998/3000
# Processing epoch 999/3000
# Processing epoch 1000/3000
# Processing epoch 1001/3000
#
# Epoch 1001 completed
# Critic loss (average): -0.4968263859318448
# Generator loss (average): -0.9249130442296998
#
# EMD (average): 0.006640452824180959
# ACF RMSE (average): 0.04739714857878299
# VOLATILITY RMSE (average): 0.32802834247187335
# LEVERAGE RMSE (average): 0.08805294910057174
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.041471443395004144 0.036610765934320784
# Min-Max values after Lambert:  -3.1614620709099412 2.754062423747635
#
# Processing epoch 1002/3000
# Processing epoch 1003/3000
# Processing epoch 1004/3000
# Processing epoch 1005/3000
# Processing epoch 1006/3000
# Processing epoch 1007/3000
# Processing epoch 1008/3000
# Processing epoch 1009/3000
# Processing epoch 1010/3000
# Processing epoch 1011/3000
# Processing epoch 1012/3000
# Processing epoch 1013/3000
# Processing epoch 1014/3000
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.04338435465097136 0.04569495568187851
# Min-Max values after Lambert:  -3.3063846273792854 3.44228253723273
#
# Processing epoch 2602/3000
# Processing epoch 2603/3000
# Processing epoch 2604/3000
# Processing epoch 2605/3000
# Processing epoch 2606/3000
# Processing epoch 2607/3000
# Processing epoch 2608/3000
# Processing epoch 2609/3000
# Processing epoch 2610/3000
# Processing epoch 2611/3000
# Processing epoch 2612/3000
# Processing epoch 2613/3000
# Processing epoch 2614/3000
# Processing epoch 2615/3000
# Processing epoch 2616/3000
# Processing epoch 2617/3000
# Processing epoch 2618/3000
# Processing epoch 2619/3000
# Processing epoch 2620/3000
# Processing epoch 2621/3000
# Processing epoch 2622/3000
# Processing epoch 2623/3000
# Processing epoch 2624/3000
# Processing epoch 2625/3000
# Processing epoch 2626/3000
# Processing epoch 2627/3000
# Processing epoch 2628/3000
# Processing epoch 2629/3000
# Processing epoch 2630/3000
# Processing epoch 2631/3000
# Processing epoch 2632/3000
# Processing epoch 2633/3000
# Processing epoch 2634/3000
# Processing epoch 2635/3000
# Processing epoch 2636/3000
# Processing epoch 2637/3000
# Processing epoch 2638/3000
# Processing epoch 2639/3000
# Processing epoch 2640/3000
# Processing epoch 2641/3000
# Processing epoch 2642/3000
# Processing epoch 2643/3000
# Processing epoch 2644/3000
# Processing epoch 2645/3000
# Processing epoch 2646/3000
# Processing epoch 2647/3000
# Processing epoch 2648/3000
# Processing epoch 2649/3000
# Processing epoch 2650/3000
# Processing epoch 2651/3000
# Processing epoch 2652/3000
# Processing epoch 2653/3000
# Processing epoch 2654/3000
# Processing epoch 2655/3000
# Processing epoch 2656/3000
# Processing epoch 2657/3000
# Processing epoch 2658/3000
# Processing epoch 2659/3000
# Processing epoch 2660/3000
# Processing epoch 2661/3000
# Processing epoch 2662/3000
# Processing epoch 2663/3000
# Processing epoch 2664/3000
# Processing epoch 2665/3000
# Processing epoch 2666/3000
# Processing epoch 2667/3000
# Processing epoch 2668/3000
# Processing epoch 2669/3000
# Processing epoch 2670/3000
# Processing epoch 2671/3000
# Processing epoch 2672/3000
# Processing epoch 2673/3000
# Processing epoch 2674/3000
# Processing epoch 2675/3000
# Processing epoch 2676/3000
# Processing epoch 2677/3000
# Processing epoch 2678/3000
# Processing epoch 2679/3000
# Processing epoch 2680/3000
# Processing epoch 2681/3000
# Processing epoch 2682/3000
# Processing epoch 2683/3000
# Processing epoch 2684/3000
# Processing epoch 2685/3000
# Processing epoch 2686/3000
# Processing epoch 2687/3000
# Processing epoch 2688/3000
# Processing epoch 2689/3000
# Processing epoch 2690/3000
# Processing epoch 2691/3000
# Processing epoch 2692/3000
# Processing epoch 2693/3000
# Processing epoch 2694/3000
# Processing epoch 2695/3000
# Processing epoch 2696/3000
# Processing epoch 2697/3000
# Processing epoch 2698/3000
# Processing epoch 2699/3000
# Processing epoch 2700/3000
# Processing epoch 2701/3000
#
# Epoch 2701 completed
# Critic loss (average): -0.26406416871982585
# Generator loss (average): -1.5718185935430093
#
# EMD (average): 0.004182601883219025
# ACF RMSE (average): 0.03946871904202999
# VOLATILITY RMSE (average): 0.22622977362945149
# LEVERAGE RMSE (average): 0.0790976417570403
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.0566730141882274 0.04779667478061019
# Min-Max values after Lambert:  -4.3131362506876725 3.6015092153227366
#
# Processing epoch 2702/3000
# Processing epoch 2703/3000
# Processing epoch 2704/3000
# Processing epoch 2705/3000
# Processing epoch 2706/3000
# Processing epoch 2707/3000
# Processing epoch 2708/3000
# Processing epoch 2709/3000
# Processing epoch 2710/3000
# Processing epoch 2711/3000
# Processing epoch 2712/3000
# Processing epoch 2713/3000
# Processing epoch 2714/3000
# Processing epoch 2715/3000
# Processing epoch 2716/3000
# Processing epoch 2717/3000
# Processing epoch 2718/3000
# Processing epoch 2719/3000
# Processing epoch 2720/3000
# Processing epoch 2721/3000
# Processing epoch 2722/3000
# Processing epoch 2723/3000
# Processing epoch 2724/3000
# Processing epoch 2725/3000
# Processing epoch 2726/3000
# Processing epoch 2727/3000
# Processing epoch 2728/3000
# Processing epoch 2729/3000
# Processing epoch 2730/3000
# Processing epoch 2731/3000
# Processing epoch 2732/3000
# Processing epoch 2733/3000
# Processing epoch 2734/3000
# Processing epoch 2735/3000
# Processing epoch 2736/3000
# Processing epoch 2737/3000
# Processing epoch 2738/3000
# Processing epoch 2739/3000
# Processing epoch 2740/3000
# Processing epoch 2741/3000
# Processing epoch 2742/3000
# Processing epoch 2743/3000
# Processing epoch 2744/3000
# Processing epoch 2745/3000
# Processing epoch 2746/3000
# Processing epoch 2747/3000
# Processing epoch 2748/3000
# Processing epoch 2749/3000
# Processing epoch 2750/3000
# Processing epoch 2751/3000
# Processing epoch 2752/3000
# Processing epoch 2753/3000
# Processing epoch 2754/3000
# Processing epoch 2755/3000
# Processing epoch 2756/3000
# Processing epoch 2757/3000
# Processing epoch 2758/3000
# Processing epoch 2759/3000
# Processing epoch 2760/3000
# Processing epoch 2761/3000
# Processing epoch 2762/3000
# Processing epoch 2763/3000
# Processing epoch 2764/3000
# Processing epoch 2765/3000
# Processing epoch 2766/3000
# Processing epoch 2767/3000
# Processing epoch 2768/3000
# Processing epoch 2769/3000
# Processing epoch 2770/3000
# Processing epoch 2771/3000
# Processing epoch 2772/3000
# Processing epoch 2773/3000
# Processing epoch 2774/3000
# Processing epoch 2775/3000
# Processing epoch 2776/3000
# Processing epoch 2777/3000
# Processing epoch 2778/3000
# Processing epoch 2779/3000
# Processing epoch 2780/3000
# Processing epoch 2781/3000
# Processing epoch 2782/3000
# Processing epoch 2783/3000
# Processing epoch 2784/3000
# Processing epoch 2785/3000
# Processing epoch 2786/3000
# Processing epoch 2787/3000
# Processing epoch 2788/3000
# Processing epoch 2789/3000
# Processing epoch 2790/3000
# Processing epoch 2791/3000
# Processing epoch 2792/3000
# Processing epoch 2793/3000
# Processing epoch 2794/3000
# Processing epoch 2795/3000
# Processing epoch 2796/3000
# Processing epoch 2797/3000
# Processing epoch 2798/3000
# Processing epoch 2799/3000
# Processing epoch 2800/3000
# Processing epoch 2801/3000
#
# Epoch 2801 completed
# Critic loss (average): -0.4597940792204257
# Generator loss (average): -1.5978793850640425
#
# EMD (average): 0.004414364417608827
# ACF RMSE (average): 0.04771388436663837
# VOLATILITY RMSE (average): 0.19657521652280932
# LEVERAGE RMSE (average): 0.08266496190367736
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.06471110292559693 0.06440395088843798
# Min-Max values after Lambert:  -4.922103533050195 4.8596799234676595
#
# Processing epoch 2802/3000
# Processing epoch 2803/3000
# Processing epoch 2804/3000
# Processing epoch 2805/3000
# Processing epoch 2806/3000
# Processing epoch 2807/3000
# Processing epoch 2808/3000
# Processing epoch 2809/3000
# Processing epoch 2810/3000
# Processing epoch 2811/3000
# Processing epoch 2812/3000
# Processing epoch 2813/3000
# Processing epoch 2814/3000
# Processing epoch 2815/3000
# Processing epoch 2816/3000
# Processing epoch 2817/3000
# Processing epoch 2818/3000
# Processing epoch 2819/3000
# Processing epoch 2820/3000
# Processing epoch 2821/3000
# Processing epoch 2822/3000
# Processing epoch 2823/3000
# Processing epoch 2824/3000
# Processing epoch 2825/3000
# Processing epoch 2826/3000
# Processing epoch 2827/3000
# Processing epoch 2828/3000
# Processing epoch 2829/3000
# Processing epoch 2830/3000
# Processing epoch 2831/3000
# Processing epoch 2832/3000
# Processing epoch 2833/3000
# Processing epoch 2834/3000
# Processing epoch 2835/3000
# Processing epoch 2836/3000
# Processing epoch 2837/3000
# Processing epoch 2838/3000
# Processing epoch 2839/3000
# Processing epoch 2840/3000
# Processing epoch 2841/3000
# Processing epoch 2842/3000
# Processing epoch 2843/3000
# Processing epoch 2844/3000
# Processing epoch 2845/3000
# Processing epoch 2846/3000
# Processing epoch 2847/3000
# Processing epoch 2848/3000
# Processing epoch 2849/3000
# Processing epoch 2850/3000
# Processing epoch 2851/3000
# Processing epoch 2852/3000
# Processing epoch 2853/3000
# Processing epoch 2854/3000
# Processing epoch 2855/3000
# Processing epoch 2856/3000
# Processing epoch 2857/3000
# Processing epoch 2858/3000
# Processing epoch 2859/3000
# Processing epoch 2860/3000
# Processing epoch 2861/3000
# Processing epoch 2862/3000
# Processing epoch 2863/3000
# Processing epoch 2864/3000
# Processing epoch 2865/3000
# Processing epoch 2866/3000
# Processing epoch 2867/3000
# Processing epoch 2868/3000
# Processing epoch 2869/3000
# Processing epoch 2870/3000
# Processing epoch 2871/3000
# Processing epoch 2872/3000
# Processing epoch 2873/3000
# Processing epoch 2874/3000
# Processing epoch 2875/3000
# Processing epoch 2876/3000
# Processing epoch 2877/3000
# Processing epoch 2878/3000
# Processing epoch 2879/3000
# Processing epoch 2880/3000
# Processing epoch 2881/3000
# Processing epoch 2882/3000
# Processing epoch 2883/3000
# Processing epoch 2884/3000
# Processing epoch 2885/3000
# Processing epoch 2886/3000
# Processing epoch 2887/3000
# Processing epoch 2888/3000
# Processing epoch 2889/3000
# Processing epoch 2890/3000
# Processing epoch 2891/3000
# Processing epoch 2892/3000
# Processing epoch 2893/3000
# Processing epoch 2894/3000
# Processing epoch 2895/3000
# Processing epoch 2896/3000
# Processing epoch 2897/3000
# Processing epoch 2898/3000
# Processing epoch 2899/3000
# Processing epoch 2900/3000
# Processing epoch 2901/3000
#
# Epoch 2901 completed
# Critic loss (average): -0.3185689646061053
# Generator loss (average): -1.6698843383848772
#
# EMD (average): 0.004615407377100605
# ACF RMSE (average): 0.054587869561284565
# VOLATILITY RMSE (average): 0.19767752947407066
# LEVERAGE RMSE (average): 0.0836480055972064
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.05088252043936449 0.04501737793935119
# Min-Max values after Lambert:  -3.8744472343063747 3.390949105873869
#
#
# QGAN training completed. Training time: --- 45.76 hours ---

# %% [markdown]
# ## Plot Training History

# %%
critic_loss = tf.squeeze(qgan.critic_loss_avg, axis=(1,2)).numpy()
generator_loss = np.array(qgan.generator_loss_avg)

window = 50
generator_ma = np.convolve(generator_loss, np.ones(window)/window, mode='valid')
critic_ma = np.convolve(critic_loss, np.ones(window)/window, mode='valid')

# plot the graphs side-by-side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))

# plot the critic loss moving average as a line
axes[0].plot(range(window-1, len(critic_loss)), critic_ma, label='Average Critic Loss', color='blue')
# plot the critic loss
axes[0].plot(critic_loss, color='black', alpha=0.2)

# plot the generator loss moving average as a line
axes[0].plot(range(window-1, len(generator_loss)), generator_ma, label='Average Generator Loss', color='orange')
# plot the generator loss
axes[0].plot(generator_loss, color='black', alpha=0.2)


axes[0].set_ylabel('Loss')
axes[0].legend()
axes[0].grid()

emd_avg = np.array(qgan.emd_avg)
emd_ma = np.convolve(emd_avg, np.ones(window)/window, mode='valid')

axes[1].plot(range(window-1, len(emd_avg)), emd_ma, label='EMD', color='red')
axes[1].plot(emd_avg, color='red', linewidth=0.5, alpha=0.5)

axes[1].set_ylabel('EMD')
axes[1].legend()
axes[1].grid()

acf_avg = np.array(qgan.acf_avg)
vol_avg = np.array(qgan.vol_avg)
lev_avg = np.array(qgan.lev_avg)

acf_ma = np.convolve(acf_avg, np.ones(window)/window, mode='valid')
vol_ma = np.convolve(vol_avg, np.ones(window)/window, mode='valid')
lev_ma = np.convolve(lev_avg, np.ones(window)/window, mode='valid')

# Creating a twin axes for the second graph
axes2 = axes[1].twinx()

axes2.plot(range(window-1, len(acf_avg)), acf_ma, label='ACF', color='green')
axes2.plot(acf_avg, color='green', linewidth=0.5, alpha=0.4)

axes2.plot(range(window-1, len(vol_avg)), vol_ma, label='Volatility Clustering', color='black')
axes2.plot(vol_avg, color='black', linewidth=0.5, alpha=0.3)

axes2.plot(range(window-1, len(lev_avg)), lev_ma, label='Leverage Effect', color='orange')

axes2.set_ylabel('Temporal Metrics')
axes2.legend()
axes2.grid()

# Adjusting the spacing between subplots
plt.tight_layout()

# %% [markdown]
# ## Plot Generated Data Properties

# %%
# generate noise
num_samples = len(sp500_log_r_tf) // WINDOW_LENGTH
input_circuits_batch = []
for _ in range(num_samples):
    noise_values = np.random.uniform(0, 2 * np.pi, size=NUM_QUBITS)
    input_circuits_batch.append(qgan.encoding_layer(noise_values))
    
# convert to tensorflow quantum tensor
generator_inputs = tfq.convert_to_tensor(input_circuits_batch)
# generate fake samples using the generator
batch_generated = qgan.generator(generator_inputs)
# concatenate all time series data into one
generated_data = tf.reshape(batch_generated, shape=(num_samples*WINDOW_LENGTH,))
generated_data = tf.cast(generated_data, dtype=tf.float64)
# rescale
generated_data = rescale(generated_data, transformed_sp500)
# reverse the preprocessing on generated sample
original_norm = lambert_w_transform(generated_data, 1)
fake_original = denormalize(original_norm, tf.reduce_mean(sp500_log_r_tf), tf.math.reduce_std(sp500_log_r_tf))

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
###################################################################################################################
#
# plot original log-returns on the left and the generated on the right
#
###################################################################################################################
axes[0].plot(date[1:], sp500_log_r_tf)
axes[0].set_xlabel('Days')
axes[0].set_title('Original Log-Returns')
axes[0].grid()

axes[1].plot(fake_original)
axes[1].set_xlabel('Days')
axes[1].set_title('Generated Log-Returns')
axes[1].grid()

plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
###################################################################################################################
#
# plot histogram of generated along with original log-returns on the left and the Q-Q plot on the right
#
###################################################################################################################
bin_edges = np.linspace(-0.05, 0.05, num=50)  # define the bin edges
bin_width = bin_edges[1] - bin_edges[0]
bin_edges = np.append(bin_edges, bin_edges[-1] + bin_width)
axes[0].hist(fake_original, bins=bin_edges, density=True, width=0.001, label='Generated', alpha=0.9)
axes[0].hist(sp500_log_r_tf, bins=bin_edges, density=True, width=0.001, label='Original', alpha=0.8)
axes[0].set_title('Original vs Generated Density')
axes[0].grid()
axes[0].legend()

probplot(fake_original, dist='norm', plot=axes[1])
axes[1].set_xlabel('Theoretical Quantiles')
axes[1].grid()

plt.subplots_adjust(wspace=0.3)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
###################################################################################################################
#
# plot autocorrelations of original log-returns on the left and the generated on the right
#
###################################################################################################################
tsaplots.plot_acf(sp500_log_r_tf, ax=axes[0], lags=18, zero=False)
axes[0].set_xlabel('Lags')
axes[0].set_title('ACF Log-Returns')
axes[0].grid()

tsaplots.plot_acf(fake_original, ax=axes[1], lags=18, zero=False)
axes[1].set_xlabel('Lags')
axes[1].set_title('ACF Log-Returns (Generated)')
axes[1].grid()

plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
###################################################################################################################
#
# plot volatility clustering of original log-returns on the left and the generated on the right
#
###################################################################################################################
tsaplots.plot_acf(tf.abs(sp500_log_r_tf), ax=axes[0], lags=18, zero=False)
axes[0].set_xlabel('Lags')
axes[0].set_title('ACF Absolute Log-Returns')
axes[0].grid()

tsaplots.plot_acf(tf.abs(fake_original), ax=axes[1], lags=18, zero=False)
axes[1].set_xlabel('Lags')
axes[1].set_title('ACF Absolute Log-Returns (Generated)')
axes[1].grid()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
###################################################################################################################
#
# plot leverage effect of original log-returns on the left and the generated on the right
#
###################################################################################################################
# compute leverage effect for maximum lags = 18
leverage_original = []
for lag in range(1, 19):
    # slice the tensors to get the appropriate lagged sequences
    r_t = sp500_log_r_tf[:-lag]
    squared_lag_r = tf.square(tf.abs(sp500_log_r_tf[lag:]))
                       
    # calculate the leverage effect
    # calculate the correlation coefficient
    correlation_matrix = np.corrcoef(r_t, squared_lag_r)
    leverage_original.append(correlation_matrix[0, 1])
    
leverage_generated = []
for lag in range(1, 19):
    # slice the tensors to get the appropriate lagged sequences
    r_t = fake_original[:-lag]
    squared_lag_r = tf.square(tf.abs(fake_original[lag:]))
                
    # calculate the leverage effect
    # calculate the correlation coefficient
    correlation_matrix = np.corrcoef(r_t, squared_lag_r)
    leverage_generated.append(correlation_matrix[0, 1])

axes[0].plot(leverage_original)
axes[0].set_xlabel('Lags')
axes[0].set_title('Original Leverage Effect')
axes[0].grid()

axes[1].plot(leverage_generated)
axes[1].set_xlabel('Lags')
axes[1].set_title('Generated Leverage Effect')
axes[1].grid()
