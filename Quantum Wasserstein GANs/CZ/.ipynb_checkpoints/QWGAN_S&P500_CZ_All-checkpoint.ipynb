# %% [markdown]
# # Generating Financial Time Series with a Quantum Wasserstein GAN
#
# ### PQC Characteristics
#  - Rotation layers (RX*RY*RZ - Parameterized)
#  - Entangling layers (CZ - All-to-all - Not Parameterized)

# %%
# hide tensorflow warnings on GPU execution (we will use CPU)
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

# disable GPU usage
import os
os.environ["CUDA_VISIBLE_DEVICES"] = ""

import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm, wasserstein_distance, probplot
from scipy.special import lambertw
from statsmodels.graphics import tsaplots
import statsmodels.api as sm
import time
import cirq, random, sympy
import tensorflow_quantum as tfq
import tensorflow as tf
from cirq.contrib.svg import SVGCircuit
from cirq.circuits import InsertStrategy

# limit GPU memory growth to avoid OUT_OF_MEMORY issues (before initializing GPU -- if used)
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e:
        print(e)

# download daily S&P 500 data from Yahoo Finance from 1/1/2008 since 31/12/2022
sp500 = yf.download('^GSPC', start='2008-01-01', end='2022-12-31')

# pandas DataFrame with 6 columns, (Open, High, Low, Close, Adj Close, and Volume values)
# extract daily closing values as a numpy array
sp500_close = tf.convert_to_tensor(sp500['Close'].values)

# display the shape of the numpy array
print('S&P500 shape (total days): ', tf.shape(sp500_close))

# check if GPU is available
print("GPU Available:", tf.config.list_physical_devices('GPU'))

# check which GPU is being used
print("GPU Device:", tf.test.gpu_device_name())

df = sp500.reset_index()
date = df['Date']
# plot the S&P 500 data
plt.plot(date, sp500_close)
plt.xlabel('Days')
plt.ylabel('S&P 500 Closing Value')
plt.title('S&P 500 Index')
plt.grid()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# S&P500 shape (total days):  tf.Tensor([3777], shape=(1,), dtype=int32)
# GPU Available: []
# GPU Device:

# %%
# direct returns over time
sp500_direct_r = sp500_close[1:] - sp500_close[:-1]
    
# logarithmic returns over time
sp500_log_r = np.log(sp500_close[1:]) - np.log(sp500_close[:-1])

# plot the graphs side-by-side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))

axes[0].plot(date[1:], sp500_direct_r)
axes[0].set_title('S&P 500 Index Direct Returns')
axes[0].grid()

axes[1].plot(date[1:], sp500_log_r)
axes[1].set_title('S&P 500 Index Log Returns')
axes[1].grid()
    
# Show the plot
plt.show()

# %%
# plot the graphs side-by-side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))

# density of log-returns
bin_edges = np.linspace(-0.05, 0.05, num=50)  # define the bin edges
bin_width = bin_edges[1] - bin_edges[0]
bin_edges = np.append(bin_edges, bin_edges[-1] + bin_width)
axes[0].hist(sp500_log_r, bins=bin_edges, density=True, width=0.001, label='Log-returns density')
axes[0].grid()

# normal distribution with same mean and standard deviation as log-returns
mu = np.mean(sp500_log_r)
sigma = np.std(sp500_log_r)

# Generate a set of points x
x = np.linspace(-0.05, 0.05, 100)

# Generate the Gaussian PDF for the points x with same mean and standard deviation as the log-returns
pdf = norm.pdf(x, mu, sigma)

# plot the Gaussian PDF
axes[0].plot(x, pdf, 'r', label='Gaussian distribution')
axes[0].legend()

# plot in logarithmic scale
axes[1].hist(sp500_log_r, bins=bin_edges, density=True, width=0.001, log=True)
axes[1].grid()

# plot the Gaussian PDF in logarithmic scale
axes[1].semilogy(x, pdf, 'r')

plt.show()

# %%
# convert the S&P 500 log returns to a TensorFlow tensor
sp500_log_r_tf = tf.convert_to_tensor(sp500_log_r)
# plot the ACF for the specified lags
tsaplots.plot_acf(sp500_log_r_tf, lags=18, zero=False)
plt.xlabel('Lags')
plt.title('ACF S&P 500 Log-Returns')
plt.ylabel(r'$\rho$')
plt.grid()
plt.show()

# %%
# plot the ACF of absolute log-returns for the specified lags
tsaplots.plot_acf(tf.abs(sp500_log_r_tf), lags=18, zero=False)
plt.xlabel('Lags')
plt.title('ACF S&P 500 Absolute Log-Returns')
plt.ylabel(r'$\rho_{abs}$')
plt.grid()
plt.show()

# %%
lags = range(1, 19)
lev = []
for lag in lags:
    # slice the tensors to get the appropriate lagged sequences
    r_t = sp500_log_r_tf[:-lag]
    squared_lag_r = tf.square(tf.abs(sp500_log_r_tf[lag:]))
                
    # calculate the leverage effect
    # calculate the correlation coefficient
    correlation_matrix = np.corrcoef(r_t, squared_lag_r)
    lev.append(correlation_matrix[0, 1])

# plot the the levarage effect
plt.plot(lev)
plt.title('Leverage Effect S&P 500')
plt.xlabel('Lags')
plt.ylabel(r'$L(\tau)$')
plt.grid()
plt.show()

# %%
# Generate the Q-Q plot
plt.figure(figsize=(6, 4))
probplot(sp500_log_r_tf, dist='norm', plot=plt)
plt.title('Q-Q Plot - S&P 500 Log Returns')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Implementation

# %% [markdown]
# ### Data Pre-Processing

# %% [markdown]
# #### (1) Normalization

# %%
def normalize(data):
    mu = tf.reduce_mean(data)
    std = tf.math.reduce_std(data)
    
    return (data - mu)/std

# %%
def denormalize(norm_data, mu_original, std_original):
    return norm_data*std_original + mu_original

# %%
# normalize the log-returns
sp500_norm_r = normalize(sp500_log_r_tf)
# display the mean and standard deviation of the original log-returns
print(f'Original S&P 500 log-returns mean = {tf.reduce_mean(sp500_log_r_tf)}, std = {tf.math.reduce_std(sp500_log_r_tf)}')
# display the mean and standard deviation of the normalized log-returns
print(f'Normalized S&P 500 log-returns mean = {tf.reduce_mean(sp500_norm_r)}, std = {tf.math.reduce_std(sp500_norm_r)}')
# Out:
# Original S&P 500 log-returns mean = 0.0002584054849133775, std = 0.013199541207181623
# Normalized S&P 500 log-returns mean = -1.8817339400426382e-18, std = 0.9999999999999999

# %%
print('Original Data Min-Max')
print(tf.reduce_min(sp500_log_r_tf).numpy(), tf.reduce_max(sp500_log_r_tf).numpy())

print('Normalized Data Min-Max')
print(tf.reduce_min(sp500_norm_r).numpy(), tf.reduce_max(sp500_norm_r).numpy())
# Out:
# Original Data Min-Max
# -0.12765219747281709 0.10957196759533883
# Normalized Data Min-Max
# -9.690534007965118 8.281618307381017

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(7,4))

# density of log-returns
bin_edges = np.linspace(-6, 6, num=100)  # define the bin edges
bin_width = bin_edges[1] - bin_edges[0]
bin_edges = np.append(bin_edges, bin_edges[-1] + bin_width)
axes.hist(sp500_norm_r, bins=bin_edges, density=True, width=0.1, label='Normalized density')
axes.grid()

# normal distribution with same mean and standard deviation as log-returns
mu = np.mean(sp500_norm_r)
sigma = np.std(sp500_norm_r)

# Generate a set of points x
x = np.linspace(-6, 6, 100)

# Generate the Gaussian PDF for the points x with same mean and standard deviation as the log-returns
pdf = norm.pdf(x, mu, sigma)

# plot the Gaussian PDF
axes.plot(x, pdf, 'r', label='Gaussian')
axes.legend()

plt.show()

# %% [markdown]
# #### (2) Inverse Lambert W Transform

# %%
def inverse_lambert_w_transform(data, delta):
    """
    Apply inverse Lambert W transform to the input data using the specified delta value.

    Parameters:
    - data: Input data tensor
    - delta: Delta value for the transform (tail parameter)

    Returns:
    - Transformed data array
    """
    sign = tf.sign(tf.cast(data, dtype=tf.float64))  
    transformed_data = sign * tf.cast(tf.sqrt(lambertw(delta * data ** 2).real / delta), dtype=tf.float64)
   
    return transformed_data

def lambert_w_transform(transformed_data, delta, clip_low=-12.0, clip_high=11.0):
    """
    Transform the Gaussianized data back to its original state.

    Parameters:
    - transformed_data: Input data array which was transformed using inverse Lambert W
    - delta: Delta value for the transform (tail parameter)

    Returns:
    - Original Data
    """
    reversed_data = transformed_data*tf.cast(tf.exp((delta/2) * transformed_data ** 2), dtype=tf.float64)
    return tf.clip_by_value(reversed_data, clip_low, clip_high)

# %%
# apply inverse Lambert W transform to the normalized log-returns
transformed_sp500 = inverse_lambert_w_transform(sp500_norm_r, 1)

fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(7,4))

# density of normalized log-returns
bin_edges = np.linspace(-3, 3, num=50)  # define the bin edges
bin_width = bin_edges[1] - bin_edges[0]
bin_edges = np.append(bin_edges, bin_edges[-1] + bin_width)
axes.hist(transformed_sp500, bins=bin_edges, density=True, width=0.1, label='Transformed log-returns')
axes.grid()

# normal distribution with same mean and standard deviation as log-returns
mu = np.mean(transformed_sp500)
sigma = np.std(transformed_sp500)

# Generate a set of points x
x = np.linspace(-3, 3, 100)

# Generate the Gaussian PDF for the points x with same mean and standard deviation as the normalized log-returns
pdf = norm.pdf(x, mu, sigma)

# plot the Gaussian PDF
axes.plot(x, pdf, 'r', label='Gaussian')
axes.legend()

plt.show()

# %%
# Generate the Q-Q plot
plt.figure(figsize=(6, 4))
probplot(transformed_sp500, dist='norm', plot=plt)
plt.title('Q-Q Plot - Transformed S&P 500 Log Returns')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')
plt.grid(True)
plt.show()

# %%
print('Transformed Data Min-Max')
print(tf.reduce_min(transformed_sp500).numpy(), tf.reduce_max(transformed_sp500).numpy())
# Out:
# Transformed Data Min-Max
# -1.8267935183456632 1.7599676089068168

# %%
print('Transformed data mean: ', tf.reduce_mean(transformed_sp500).numpy())
print('Transformed data std: ', tf.math.reduce_std(transformed_sp500).numpy())
# Out:
# Transformed data mean:  0.014927970271913928
# Transformed data std:  0.5588396501296408

# %% [markdown]
# #### (3) Scale to [-1,1]
#
# Necessary scaling to match the range of expectation values.

# %%
min_val = tf.reduce_min(transformed_sp500)
max_val = tf.reduce_max(transformed_sp500)
scaled_data = -1.0 + 2.0 * (transformed_sp500 - min_val) / (max_val - min_val)

# %%
print(f'Scaled Normalized Transformed log-returns mean = {tf.reduce_mean(scaled_data)}, std = {tf.math.reduce_std(scaled_data)}')
print('Scaled Normalized Transformed log-returns min-max: ', tf.reduce_min(scaled_data).numpy(), tf.reduce_max(scaled_data).numpy())
# Out:
# Scaled Normalized Transformed log-returns mean = 0.026955196220924363, std = 0.31161241593901257
# Scaled Normalized Transformed log-returns min-max:  -1.0 1.0

# %%
# a function to scale back from [-1,1] to the previous range
def rescale(scaled_data, rescaled_data):
    min_val = tf.reduce_min(rescaled_data)
    previous_data = 0.5 * (scaled_data + 1.0) * (max_val - min_val) + min_val
    
    return previous_data

# %% [markdown]
# #### (4) Rolling Window

# %%
def rolling_window(data, m, s):
    return tf.map_fn(lambda i: data[i:i+m], tf.range(0, len(data) - m + 1, s), dtype=tf.float64)

# %% [markdown]
# ## qGAN

# %%
class qGAN(tf.keras.Model):
    
    def __init__(self, num_epochs, batch_size, window_length, n_critic, gp, num_layers, num_qubits):
        super(qGAN, self).__init__()
        
        # classical hyperparameters
        self.num_epochs = num_epochs
        self.batch_size = batch_size
        self.window_length = window_length
        self.n_critic = n_critic
        self.gp = gp
        
        # quantum hyperparameters
        # one layer corresponds to a rotation and an entangling layer together
        self.num_layers = num_layers
        self.num_qubits = num_qubits
        
        # quantum circuit settings
        self.qubits = cirq.GridQubit.rect(1, num_qubits)
        # create the set of Pauli strings to measure -> {X1, Z1, X2, Z2, etc}
        # X1 means we measure the first qubit only with X, Z1 the first qubit only with Z and so on...
        self.measurements = []
        for qubit in self.qubits:
            self.measurements.append(cirq.X(qubit))
            self.measurements.append(cirq.Z(qubit))
            
        # number of parameters of the PQC and re-uploading layers
        self.num_params = self.count_params()
        
        # define the trainable parameters of the PQC main and re-uploading layers (trainable)
        self.params_pqc = [sympy.Symbol(f'theta{i}') for i in range(self.num_params)]
        
        # define the classical critic network (CNN)
        self.critic = self.define_critic_model(window_length)
        # define the quantum generator network (PQC)
        self.generator = self.define_generator_model()
        
        # monitoring purposes
        # average critic and generator losses for each epoch
        self.critic_loss_avg = []
        self.generator_loss_avg = []
        # Earth's mover distance (EMD) for each epoch
        self.emd_avg = []
        # stylized facts RMSEs for each epoch
        self.acf_avg = []
        self.vol_avg = []
        self.lev_avg = []
        
    ####################################################################################
    #
    # count the parameters of the quantum circuit
    #
    ####################################################################################
    def count_params(self):
        
        # rotation layer with Rx, Ry, Rz has 3N parameters, where N is the number of qubits
        # the entangling layer is not parameterized
        num_params_pqc = 3*self.num_qubits*self.num_layers
        
        # also, count the parameters of the re-uploading layer that is sandwiched between rotation-entangling layers
        # there is one re-uploading layer after each rotation-entangling layer with a parameterized Rx gate,
        # so the number of parameters is equal to the number of qubits for each re-uploading layer
        num_params_upload = self.num_layers*self.num_qubits
        
        # the last layer of the PQC is a rotation layer
        num_params_pqc += 3*self.num_qubits
                    
        return num_params_pqc+num_params_upload
    
    ####################################################################################
    #
    # the classical critic model as a convolutional network
    #
    ####################################################################################  
    def define_critic_model(self, window_length):
        model = tf.keras.Sequential()
        model.add(tf.keras.layers.Conv1D(filters=64, kernel_size=10, strides=1, input_shape=(window_length, 1), padding='same'))
        model.add(tf.keras.layers.LeakyReLU(alpha=0.1))

        model.add(tf.keras.layers.Conv1D(filters=128, kernel_size=10, strides=1, padding='same'))
        model.add(tf.keras.layers.LeakyReLU(alpha=0.1))

        model.add(tf.keras.layers.Conv1D(filters=128, kernel_size=10, strides=1, padding='same'))
        model.add(tf.keras.layers.LeakyReLU(alpha=0.1))
    
        model.add(tf.keras.layers.Flatten())
    
        model.add(tf.keras.layers.Dense(32, dtype=tf.float64))
        model.add(tf.keras.layers.LeakyReLU(alpha=0.1))
        model.add(tf.keras.layers.Dropout(0.2))
    
        model.add(tf.keras.layers.Dense(1, dtype=tf.float64))

        return model
    
    ####################################################################################
    #
    # the encoding layer: resolve the parameters by uniform noise values,
    # used to prepare the initial state for the generator circuit
    #
    ####################################################################################
    def encoding_layer(self, noise_params):
        
        return cirq.Circuit(cirq.Rx(rads=noise_params[i])(self.qubits[i]) for i in range(self.num_qubits))
        
    ####################################################################################
    #
    # the quantum generator as a PQC with All-to-all topology for the entangling layer
    #
    #################################################################################### 
    def define_generator_circuit(self):
        
        # cirq circuit 
        pqc = cirq.Circuit()
        
        # index for the parameter tensor of the PQC main and re-uploading layers
        idx = 0
        
        for layer in range(self.num_layers):
            ###############################################################
            #
            # single-qubit rotation layer
            #
            ###############################################################
            for qubit in self.qubits:
                pqc.append(cirq.Rx(rads=self.params_pqc[idx])(qubit))
                idx += 1
                pqc.append(cirq.Ry(rads=self.params_pqc[idx])(qubit))
                idx += 1
                pqc.append(cirq.Rz(rads=self.params_pqc[idx])(qubit))
                idx += 1
            
            ###############################################################
            #
            # entangling layer (not parameterized)
            #
            ###############################################################
            for qubit1 in range(self.num_qubits):
                for qubit2 in range(qubit1+1, self.num_qubits):
                    pqc.append(cirq.CZ(self.qubits[qubit1], self.qubits[qubit2]), strategy=InsertStrategy.NEW)
            
            ###############################################################
            #
            # re-uploading layer with Rx rotation
            # (set the strategy for better readability and understanding)
            #
            ###############################################################
            for i, qubit in enumerate(self.qubits):
                if i == 0:
                    pqc.append(cirq.Rx(rads=self.params_pqc[idx])(qubit), strategy=InsertStrategy.NEW)
                else:
                    pqc.append(cirq.Rx(rads=self.params_pqc[idx])(qubit), strategy=InsertStrategy.INLINE)
                idx += 1
                
        #####################################################################
        #
        # single-qubit rotation layer as the last layer before measurement
        #
        #####################################################################
        for qubit in self.qubits:
                pqc.append(cirq.Rx(rads=self.params_pqc[idx])(qubit))
                idx += 1
                pqc.append(cirq.Ry(rads=self.params_pqc[idx])(qubit))
                idx += 1
                pqc.append(cirq.Rz(rads=self.params_pqc[idx])(qubit))
                idx += 1 
        
        return pqc
    
    ####################################################################################
    #
    # the quantum generator model
    #
    #################################################################################### 
    def define_generator_model(self):
        # model input
        q_data_input = tf.keras.Input(shape=(), dtype=tf.dtypes.string)
        # define the tensorflow quantum layer (trainable)
        generator = tfq.layers.PQC(self.define_generator_circuit(), self.measurements, repetitions=1000)
        generator_output = generator(q_data_input)
        # tensorflow model
        model = tf.keras.Model(inputs=q_data_input, outputs=generator_output)
        
        return model
    
    #############################################################################
    #
    # compile model with given optimizers for critic and generator networks
    #
    #############################################################################
    def compile_QGAN(self, c_optimizer, g_optimizer):
        super(qGAN, self).compile()
        self.c_optimizer = c_optimizer
        self.g_optimizer = g_optimizer
        
    def train_qgan(self, gan_data, original_data, preprocessed_data, num_elements):
        """
        Parameters:
         - gan_data is the preprocessed dataset with windows for qGAN training
         - original_data is the original S&P 500 log-returns for evaluation of RMSEs (monitoring purposes)
         - preprocessed_data is the preprocessed log-returns without the last normalization step and without windows
          (for reversing the process of generated samples using the mean and std and evaluating the RMSEs)
        """
        for epoch in range(self.num_epochs):
            print(f'Processing epoch {epoch+1}/{self.num_epochs}')
            ################################################################
            #
            # Train the critic for n_critic iterations
            # Process 'batch_size' samples in each iteration
            #
            ################################################################
            # critic loss for 'n_critic' iterations
            critic_t_sum = 0
            for t in range(self.n_critic):
                # record the gradients
                with tf.GradientTape() as critic_tape:
                    # critic loss for 'batch_size' samples
                    critic_sum = 0
                    for i in range(self.batch_size):
                        ###########################################
                        #
                        # Sample real data and a latent variable
                        #
                        ###########################################
                        # shuffle the dataset
                        shuffled_data = gan_data.shuffle(buffer_size=num_elements)
                        # take a single random element from the shuffled dataset
                        random_element = shuffled_data.take(1)
                        # iterate over the random_element dataset to access the value
                        for element in random_element:
                            # access the value of the random element as a tensor
                            real_sample = element
                        # reshape the real sample for compatibility with the first layer of the critic
                        real_sample = tf.reshape(real_sample, (1, self.window_length))
                    
                        ##################################################
                        #
                        # Get the state prepared by the encoding circuit
                        #
                        ##################################################
                        # generate noise parameters for the encoding layer
                        noise_values = np.random.uniform(0, 2 * np.pi, size=self.num_qubits)
                        generator_input_state = self.encoding_layer(noise_values)
                        # convert to tensorflow quantum tensor
                        generator_input = tfq.convert_to_tensor([generator_input_state])
                        # get the fake sample as the expectations of the quantum circuit
                        generated_sample = self.generator(generator_input)
                        generated_sample = tf.cast(generated_sample, dtype=tf.float64)
                        
                        # calculate the critic scores for real and fake samples
                        real_score = self.critic(real_sample)
                        fake_score = self.critic(generated_sample)
                     
                        # compute the gradient penalty
                        gradient_penalty = self.compute_gradient_penalty(real_sample, generated_sample)

                        # calculate the Wasserstein distance loss with gradient penalty
                        critic_loss = fake_score - real_score + self.gp * gradient_penalty
                        # accumulate the critic loss for the sample
                        critic_sum += critic_loss

                    # compute the gradients of critic and apply them
                    critic_gradients = critic_tape.gradient(critic_sum/self.batch_size, self.critic.trainable_variables)
                    self.c_optimizer.apply_gradients(zip(critic_gradients, self.critic.trainable_variables))
                    
                    # accumulate the average critic loss for all samples in this 't' iteration
                    critic_t_sum += critic_sum/self.batch_size
            
            # average critic loss for this epoch of WGAN training
            self.critic_loss_avg.append(critic_t_sum/self.n_critic)
            
            ################################################################
            #
            # Train generator for one iteration
            #
            ################################################################
            # sample a batch of input states using the encoding layer
            input_circuits_batch = []
            for _ in range(self.batch_size):
                noise_values = np.random.uniform(0, 2 * np.pi, size=self.num_qubits)
                input_circuits_batch.append(self.encoding_layer(noise_values))
            
            # convert to tensorflow quantum tensor
            generator_inputs = tfq.convert_to_tensor(input_circuits_batch)
                
            with tf.GradientTape() as gen_tape:
                # generate fake samples using the generator
                generated_samples = self.generator(generator_inputs)
                generated_samples = tf.cast(generated_samples, dtype=tf.float64)
                # calculate the critic scores for fake samples
                fake_scores = self.critic(generated_samples)
                # calculate the generator loss
                generator_loss = -tf.reduce_mean(fake_scores)

            # compute the gradients of generator and apply them
            generator_gradients = gen_tape.gradient(generator_loss, self.generator.trainable_variables)
            self.g_optimizer.apply_gradients(zip(generator_gradients, self.generator.trainable_variables))
            
            # average generator loss for this epoch
            self.generator_loss_avg.append(generator_loss)
            
            ########################################################################################################
            #
            # Calculate the stylized facts RMSEs and the EMD for real and fake data
            # 
            # Fake data has shape (num_samples x window_length), with num_samples = original_length / window_length
            # in order to get a time series close to the length of the original
            #
            ########################################################################################################
            # generate noise
            num_samples = len(original_data) // self.window_length
            input_circuits_batch = []
            for _ in range(num_samples):
                noise_values = np.random.uniform(0, 2 * np.pi, size=self.num_qubits)
                input_circuits_batch.append(self.encoding_layer(noise_values))
            
            # convert to tensorflow quantum tensor
            generator_inputs = tfq.convert_to_tensor(input_circuits_batch)
            # generate fake samples using the generator
            batch_generated = self.generator(generator_inputs)
            # concatenate all time series data into one
            generated_data = tf.reshape(batch_generated, shape=(num_samples*self.window_length,))
            generated_data = tf.cast(generated_data, dtype=tf.float64)
            # rescale
            generated_data = rescale(generated_data, preprocessed_data)
            # reverse the preprocessing on generated sample
            original_norm = lambert_w_transform(generated_data, 1)
            fake_original = denormalize(original_norm, tf.reduce_mean(original_data), tf.math.reduce_std(original_data))
            # calculate the temporal metrics for monitoring the training process
            corr_rmse, volatility_rmse, lev_rmse, emd = self.stylized_facts(original_data, fake_original)
            # store the EMD and RMSEs of stylized facts
            self.acf_avg.append(corr_rmse)
            self.vol_avg.append(volatility_rmse)
            self.lev_avg.append(lev_rmse)
            self.emd_avg.append(emd)
            
            # print progress every 100 epochs
            if epoch % 100 == 0 or epoch+1 == 3000:
                print(f'\nEpoch {epoch+1} completed')
                print(f'Critic loss (average): {self.critic_loss_avg[epoch][-1][0]}')
                print(f'Generator loss (average): {self.generator_loss_avg[epoch]}')
                print(f'\nEMD (average): {self.emd_avg[epoch]}')
                print(f'ACF RMSE (average): {self.acf_avg[epoch]}')
                print(f'VOLATILITY RMSE (average): {self.vol_avg[epoch]}')
                print(f'LEVERAGE RMSE (average): {self.lev_avg[epoch]}\n')
                print('Min-Max values of original log-returns: ', tf.reduce_min(original_data).numpy(), tf.reduce_max(original_data).numpy())
                print('Min-Max values of generated log-returns (for all batches): ', tf.reduce_min(fake_original).numpy(), tf.reduce_max(fake_original).numpy())
                print('Min-Max values after Lambert: ', tf.reduce_min(original_norm).numpy(), tf.reduce_max(original_norm).numpy())
                print()
    
    ###########################################################
    #
    # Sample a random number epsilon ~ U[0,1]
    # Create a convex combination of real and generated sample
    # Compute the gradient penalty for the critic network
    #
    ###########################################################
    def compute_gradient_penalty(self, real_sample, generated_sample):
        epsilon = tf.random.uniform((), dtype=tf.float64)
        interpolated_sample = epsilon * real_sample + (1 - epsilon) * generated_sample
    
        with tf.GradientTape() as tape:
            tape.watch(interpolated_sample)
            scores = self.critic(interpolated_sample)
            
        gradients = tape.gradient(scores, interpolated_sample)
        gradients_norm = tf.norm(gradients)
        gradient_penalty = (gradients_norm - 1)**2

        return gradient_penalty
    
    def stylized_facts(self, original_data, fake_original):
        """
        - Calculate the RMSEs of the stylized facts between the original S&P 500 log-returns and 
          generated time series
      
        - Evaluate the EMD between real and generated samples
        """
        
        ################################################
        #   
        # stylized facts for fake samples
        #
        ################################################
        # compute acf for maximum lags = 18
        acf_values = sm.tsa.acf(fake_original, nlags=18)
        # exclude zero lag
        acf_values_generated = tf.convert_to_tensor(acf_values[1:])
            
        # compute absolute acf (volatility clustering) for maximum lags = 18
        acf_abs_values = sm.tsa.acf(tf.abs(fake_original), nlags=18)
        # exclude zero lag
        acf_abs_values_generated = tf.convert_to_tensor(acf_abs_values[1:])
            
        # compute leverage effect for maximum lags = 18
        lev = []
        for lag in range(1, 19):
            # slice the tensors to get the appropriate lagged sequences
            r_t = fake_original[:-lag]
            squared_lag_r = tf.square(tf.abs(fake_original[lag:]))
                
            # calculate the leverage effect
            # calculate the correlation coefficient
            correlation_matrix = np.corrcoef(r_t, squared_lag_r)
            lev.append(correlation_matrix[0, 1])
            
        leverage_generated = tf.convert_to_tensor(lev)
        
        ################################################
        #   
        # stylized facts for real samples
        #
        ################################################
        
        # compute acf for maximum lags = 18
        acf_values = sm.tsa.acf(original_data, nlags=18)
        # exclude zero lag
        acf_values_original = tf.convert_to_tensor(acf_values[1:])
            
        # compute absolute acf (volatility clustering) for maximum lags = 18
        acf_abs_values = sm.tsa.acf(tf.abs(original_data), nlags=18)
        # exclude zero lag
        acf_abs_values_original = tf.convert_to_tensor(acf_abs_values[1:])
            
        # compute leverage effect for maximum lags = 18
        lev = []
        for lag in range(1, 19):
            # slice the tensors to get the appropriate lagged sequences
            r_t = original_data[:-lag]
            squared_lag_r = tf.square(tf.abs(original_data[lag:]))
                
            # calculate the leverage effect
            # calculate the correlation coefficient
            correlation_matrix = np.corrcoef(r_t, squared_lag_r)
            lev.append(correlation_matrix[0, 1])
            
        leverage_original = tf.convert_to_tensor(lev)
        
        # calculate average RMSEs of stylized facts
        # autocorrelations
        rmse_acf = tf.sqrt(tf.reduce_mean((acf_values_original-acf_values_generated)**2))
        # volatility clustering
        rmse_vol = tf.sqrt(tf.reduce_mean((acf_abs_values_original-acf_abs_values_generated)**2))
        # leverage effect
        rmse_lev = tf.sqrt(tf.reduce_mean((leverage_original-leverage_generated)**2))
        
        ####################################################################################
        #
        # compute the Earth's mover distance (EMD)
        #
        ####################################################################################
        bin_edges = np.linspace(-0.05, 0.05, num=50)  # define the bin edges
        bin_width = bin_edges[1] - bin_edges[0]
        bin_edges = np.append(bin_edges, bin_edges[-1] + bin_width)
        # compute the empirical distribution of original data
        empirical_real, _ = np.histogram(original_data, bins=bin_edges, density=True)
        empirical_real /= np.sum(empirical_real)
        # compute the empirical distribution of generated data
        empirical_fake, _ = np.histogram(fake_original, bins=bin_edges, density=True)
        empirical_fake /= np.sum(empirical_fake)
        
        # evaluate the EMD using SciPy
        emd = wasserstein_distance(empirical_real, empirical_fake)
 
        return rmse_acf, rmse_vol, rmse_lev, emd

# %%
##################################################################
#
# Hyperparameters
#
##################################################################
WINDOW_LENGTH = 20  # this must be equal to the number of Pauli strings to measure
NUM_QUBITS = 10  # number of qubits
NUM_LAYERS = 4  # number of layers for the PQC

# training hyperparameters
EPOCHS = 3000
BATCH_SIZE = 10

n_critic = 2 # number of iterations for the critic per epoch
LAMBDA = 10  # gradient penalty strength

# instantiate the QGAN model object
qgan = qGAN(EPOCHS, BATCH_SIZE, WINDOW_LENGTH, n_critic, LAMBDA, NUM_LAYERS, NUM_QUBITS)

# set the optimizers
c_optimizer = tf.keras.optimizers.Adam()
g_optimizer = tf.keras.optimizers.Adam()
qgan.compile_QGAN(c_optimizer, g_optimizer)

##################################################################################
#
# Data pre-processing
#
##################################################################################
# apply rolling window in transformed (scaled) log-returns with stride s=5
gan_data_tf = rolling_window(scaled_data, WINDOW_LENGTH, 5)
# create TensorFlow datasets
gan_data = tf.data.Dataset.from_tensor_slices(gan_data_tf)
# get the number of elements in the dataset
num_elements = gan_data.cardinality().numpy()

# %%
# display the generator circuit
SVGCircuit(qgan.define_generator_circuit())
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.

# %%
# train the QGAN
print('Training started...')
print('Number of samples to process per epoch: ', num_elements)
print()
start_time_train = time.time()
qgan.train_qgan(gan_data, sp500_log_r_tf, transformed_sp500, num_elements)
exec_time_train = time.time() - start_time_train
print(f'\nQGAN training completed. Training time: --- {exec_time_train/3600:.02f} hours ---')
# Out:
# Training started...
# Number of samples to process per epoch:  752
#
# Processing epoch 1/2000
#
# Epoch 1 completed
# Critic loss (average): 8.157413132912618
# Generator loss (average): 0.05074885633813159
#
# EMD (average): 0.022860798071346534
# ACF RMSE (average): 0.0568365593689779
# VOLATILITY RMSE (average): 0.3722461383279452
# LEVERAGE RMSE (average): 0.08960751092535248
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.022219984372106247 0.02200224513318055
# Min-Max values after Lambert:  -1.7029675125972978 1.6473178352923932
#
# Processing epoch 2/2000
# Processing epoch 3/2000
# Processing epoch 4/2000
# Processing epoch 5/2000
# Processing epoch 6/2000
# Processing epoch 7/2000
# Processing epoch 8/2000
# Processing epoch 9/2000
# Processing epoch 10/2000
# Processing epoch 11/2000
# Processing epoch 12/2000
# Processing epoch 13/2000
# Processing epoch 14/2000
# Processing epoch 15/2000
# Processing epoch 16/2000
# Processing epoch 17/2000
# Processing epoch 18/2000
# Processing epoch 19/2000
# Processing epoch 20/2000
# Processing epoch 21/2000
# Processing epoch 22/2000
# Processing epoch 23/2000
# Processing epoch 24/2000
# Processing epoch 25/2000
# Processing epoch 26/2000
# Processing epoch 27/2000
# Processing epoch 28/2000
# Processing epoch 29/2000
# Processing epoch 30/2000
# Processing epoch 31/2000
# Processing epoch 32/2000
# Processing epoch 33/2000
# Processing epoch 34/2000
# Processing epoch 35/2000
# Processing epoch 36/2000
# Processing epoch 37/2000
# Processing epoch 38/2000
# Processing epoch 39/2000
# Processing epoch 40/2000
# Processing epoch 41/2000
# Processing epoch 42/2000
# Processing epoch 43/2000
# Processing epoch 44/2000
# Processing epoch 45/2000
# Processing epoch 46/2000
# Processing epoch 47/2000
# Processing epoch 48/2000
# Processing epoch 49/2000
# Processing epoch 50/2000
# Processing epoch 51/2000
# Processing epoch 52/2000
# Processing epoch 53/2000
# Processing epoch 54/2000
# Processing epoch 55/2000
# Processing epoch 56/2000
# Processing epoch 57/2000
# Processing epoch 58/2000
# Processing epoch 59/2000
# Processing epoch 60/2000
# Processing epoch 61/2000
# Processing epoch 62/2000
# Processing epoch 63/2000
# Processing epoch 64/2000
# Processing epoch 65/2000
# Processing epoch 66/2000
# Processing epoch 67/2000
# Processing epoch 68/2000
# Processing epoch 69/2000
# Processing epoch 70/2000
# Processing epoch 71/2000
# Processing epoch 72/2000
# Processing epoch 73/2000
# Processing epoch 74/2000
# Processing epoch 75/2000
# Processing epoch 76/2000
# Processing epoch 77/2000
# Processing epoch 78/2000
# Processing epoch 79/2000
# Processing epoch 80/2000
# Processing epoch 81/2000
# Processing epoch 82/2000
# Processing epoch 83/2000
# Processing epoch 84/2000
# Processing epoch 85/2000
# Processing epoch 86/2000
# Processing epoch 87/2000
# Processing epoch 88/2000
# Processing epoch 89/2000
# Processing epoch 90/2000
# Processing epoch 91/2000
# Processing epoch 92/2000
# Processing epoch 93/2000
# Processing epoch 94/2000
# Processing epoch 95/2000
# Processing epoch 96/2000
# Processing epoch 97/2000
# Processing epoch 98/2000
# Processing epoch 99/2000
# Processing epoch 100/2000
# Processing epoch 101/2000
#
# Epoch 101 completed
# Critic loss (average): -0.9081890406218528
# Generator loss (average): -0.24434435383871125
#
# EMD (average): 0.020924627858580583
# ACF RMSE (average): 0.0499901863666466
# VOLATILITY RMSE (average): 0.3747734143625335
# LEVERAGE RMSE (average): 0.0886005875532413
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.02664512510237285 0.02590716279395434
# Min-Max values after Lambert:  -2.038217098988904 1.943155213234681
#
# Processing epoch 102/2000
# Processing epoch 103/2000
# Processing epoch 104/2000
# Processing epoch 105/2000
# Processing epoch 106/2000
# Processing epoch 107/2000
# Processing epoch 108/2000
# Processing epoch 109/2000
# Processing epoch 110/2000
# Processing epoch 111/2000
# Processing epoch 112/2000
# Processing epoch 113/2000
# Processing epoch 114/2000
# Processing epoch 115/2000
# Processing epoch 116/2000
# Processing epoch 117/2000
# Processing epoch 118/2000
# Processing epoch 119/2000
# Processing epoch 120/2000
# Processing epoch 121/2000
# Processing epoch 122/2000
# Processing epoch 123/2000
# Processing epoch 124/2000
# Processing epoch 125/2000
# Processing epoch 126/2000
# Processing epoch 127/2000
# Processing epoch 128/2000
# Processing epoch 129/2000
# Processing epoch 130/2000
# Processing epoch 131/2000
# Processing epoch 132/2000
# Processing epoch 133/2000
# Processing epoch 134/2000
# Processing epoch 135/2000
# Processing epoch 136/2000
# Processing epoch 137/2000
# Processing epoch 138/2000
# Processing epoch 139/2000
# Processing epoch 140/2000
# Processing epoch 141/2000
# Processing epoch 142/2000
# Processing epoch 143/2000
# Processing epoch 144/2000
# Processing epoch 145/2000
# Processing epoch 146/2000
# Processing epoch 147/2000
# Processing epoch 148/2000
# Processing epoch 149/2000
# Processing epoch 150/2000
# Processing epoch 151/2000
# Processing epoch 152/2000
# Processing epoch 153/2000
# Processing epoch 154/2000
# Processing epoch 155/2000
# Processing epoch 156/2000
# Processing epoch 157/2000
# Processing epoch 158/2000
# Processing epoch 159/2000
# Processing epoch 160/2000
# Processing epoch 161/2000
# Processing epoch 162/2000
# Processing epoch 163/2000
# Processing epoch 164/2000
# Processing epoch 165/2000
# Processing epoch 166/2000
# Processing epoch 167/2000
# Processing epoch 168/2000
# Processing epoch 169/2000
# Processing epoch 170/2000
# Processing epoch 171/2000
# Processing epoch 172/2000
# Processing epoch 173/2000
# Processing epoch 174/2000
# Processing epoch 175/2000
# Processing epoch 176/2000
# Processing epoch 177/2000
# Processing epoch 178/2000
# Processing epoch 179/2000
# Processing epoch 180/2000
# Processing epoch 181/2000
# Processing epoch 182/2000
# Processing epoch 183/2000
# Processing epoch 184/2000
# Processing epoch 185/2000
# Processing epoch 186/2000
# Processing epoch 187/2000
# Processing epoch 188/2000
# Processing epoch 189/2000
# Processing epoch 190/2000
# Processing epoch 191/2000
# Processing epoch 192/2000
# Processing epoch 193/2000
# Processing epoch 194/2000
# Processing epoch 195/2000
# Processing epoch 196/2000
# Processing epoch 197/2000
# Processing epoch 198/2000
# Processing epoch 199/2000
# Processing epoch 200/2000
# Processing epoch 201/2000
#
# Epoch 201 completed
# Critic loss (average): -0.911977532159095
# Generator loss (average): -0.49535758886942255
#
# EMD (average): 0.016711861901133784
# ACF RMSE (average): 0.053317737806573756
# VOLATILITY RMSE (average): 0.3550257314738645
# LEVERAGE RMSE (average): 0.0864820545356562
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.03198793569496958 0.02684745641624966
# Min-Max values after Lambert:  -2.442989545904696 2.014392054541235
#
# Processing epoch 202/2000
# Processing epoch 203/2000
# Processing epoch 204/2000
# Processing epoch 205/2000
# Processing epoch 206/2000
# Processing epoch 207/2000
# Processing epoch 208/2000
# Processing epoch 209/2000
# Processing epoch 210/2000
# Processing epoch 211/2000
# Processing epoch 212/2000
# Processing epoch 213/2000
# Processing epoch 214/2000
# Processing epoch 215/2000
# Processing epoch 216/2000
# Processing epoch 217/2000
# Processing epoch 218/2000
# Processing epoch 219/2000
# Processing epoch 220/2000
# Processing epoch 221/2000
# Processing epoch 222/2000
# Processing epoch 223/2000
# Processing epoch 224/2000
# Processing epoch 225/2000
# Processing epoch 226/2000
# Processing epoch 227/2000
# Processing epoch 228/2000
# Processing epoch 229/2000
# Processing epoch 230/2000
# Processing epoch 231/2000
# Processing epoch 232/2000
# Processing epoch 233/2000
# Processing epoch 234/2000
# Processing epoch 235/2000
# Processing epoch 236/2000
# Processing epoch 237/2000
# Processing epoch 238/2000
# Processing epoch 239/2000
# Processing epoch 240/2000
# Processing epoch 241/2000
# Processing epoch 242/2000
# Processing epoch 243/2000
# Processing epoch 244/2000
# Processing epoch 245/2000
# Processing epoch 246/2000
# Processing epoch 247/2000
# Processing epoch 248/2000
# Processing epoch 249/2000
# Processing epoch 250/2000
# Processing epoch 251/2000
# Processing epoch 252/2000
# Processing epoch 253/2000
# Processing epoch 254/2000
# Processing epoch 255/2000
# Processing epoch 256/2000
# Processing epoch 257/2000
# Processing epoch 258/2000
# Processing epoch 259/2000
# Processing epoch 260/2000
# Processing epoch 261/2000
# Processing epoch 262/2000
# Processing epoch 263/2000
# Processing epoch 264/2000
# Processing epoch 265/2000
# Processing epoch 266/2000
# Processing epoch 267/2000
# Processing epoch 268/2000
# Processing epoch 269/2000
# Processing epoch 270/2000
# Processing epoch 271/2000
# Processing epoch 272/2000
# Processing epoch 273/2000
# Processing epoch 274/2000
# Processing epoch 275/2000
# Processing epoch 276/2000
# Processing epoch 277/2000
# Processing epoch 278/2000
# Processing epoch 279/2000
# Processing epoch 280/2000
# Processing epoch 281/2000
# Processing epoch 282/2000
# Processing epoch 283/2000
# Processing epoch 284/2000
# Processing epoch 285/2000
# Processing epoch 286/2000
# Processing epoch 287/2000
# Processing epoch 288/2000
# Processing epoch 289/2000
# Processing epoch 290/2000
# Processing epoch 291/2000
# Processing epoch 292/2000
# Processing epoch 293/2000
# Processing epoch 294/2000
# Processing epoch 295/2000
# Processing epoch 296/2000
# Processing epoch 297/2000
# Processing epoch 298/2000
# Processing epoch 299/2000
# Processing epoch 300/2000
# Processing epoch 301/2000
#
# Epoch 301 completed
# Critic loss (average): -0.8066914418400868
# Generator loss (average): -0.6691658976599284
#
# EMD (average): 0.010947729624617618
# ACF RMSE (average): 0.06029344815967938
# VOLATILITY RMSE (average): 0.29843264993336943
# LEVERAGE RMSE (average): 0.08939217005862336
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.028039502199228468 0.02395752567324234
# Min-Max values after Lambert:  -2.1438553992123213 1.7954502975781246
#
# Processing epoch 302/2000
# Processing epoch 303/2000
# Processing epoch 304/2000
# Processing epoch 305/2000
# Processing epoch 306/2000
# Processing epoch 307/2000
# Processing epoch 308/2000
# Processing epoch 309/2000
# Processing epoch 310/2000
# Processing epoch 311/2000
# Processing epoch 312/2000
# Processing epoch 313/2000
# Processing epoch 314/2000
# Processing epoch 315/2000
# Processing epoch 316/2000
# Processing epoch 317/2000
# Processing epoch 318/2000
# Processing epoch 319/2000
# Processing epoch 320/2000
# Processing epoch 321/2000
# Processing epoch 322/2000
# Processing epoch 323/2000
# Processing epoch 324/2000
# Processing epoch 325/2000
# Processing epoch 326/2000
# Processing epoch 327/2000
# Processing epoch 328/2000
# Processing epoch 329/2000
# Processing epoch 330/2000
# Processing epoch 331/2000
# Processing epoch 332/2000
# Processing epoch 333/2000
# Processing epoch 334/2000
# Processing epoch 335/2000
# Processing epoch 336/2000
# Processing epoch 337/2000
# Processing epoch 338/2000
# Processing epoch 339/2000
# Processing epoch 340/2000
# Processing epoch 341/2000
# Processing epoch 342/2000
# Processing epoch 343/2000
# Processing epoch 344/2000
# Processing epoch 345/2000
# Processing epoch 346/2000
# Processing epoch 347/2000
# Processing epoch 348/2000
# Processing epoch 349/2000
# Processing epoch 350/2000
# Processing epoch 351/2000
# Processing epoch 352/2000
# Processing epoch 353/2000
# Processing epoch 354/2000
# Processing epoch 355/2000
# Processing epoch 356/2000
# Processing epoch 357/2000
# Processing epoch 358/2000
# Processing epoch 359/2000
# Processing epoch 360/2000
# Processing epoch 361/2000
# Processing epoch 362/2000
# Processing epoch 363/2000
# Processing epoch 364/2000
# Processing epoch 365/2000
# Processing epoch 366/2000
# Processing epoch 367/2000
# Processing epoch 368/2000
# Processing epoch 369/2000
# Processing epoch 370/2000
# Processing epoch 371/2000
# Processing epoch 372/2000
# Processing epoch 373/2000
# Processing epoch 374/2000
# Processing epoch 375/2000
# Processing epoch 376/2000
# Processing epoch 377/2000
# Processing epoch 378/2000
# Processing epoch 379/2000
# Processing epoch 380/2000
# Processing epoch 381/2000
# Processing epoch 382/2000
# Processing epoch 383/2000
# Processing epoch 384/2000
# Processing epoch 385/2000
# Processing epoch 386/2000
# Processing epoch 387/2000
# Processing epoch 388/2000
# Processing epoch 389/2000
# Processing epoch 390/2000
# Processing epoch 391/2000
# Processing epoch 392/2000
# Processing epoch 393/2000
# Processing epoch 394/2000
# Processing epoch 395/2000
# Processing epoch 396/2000
# Processing epoch 397/2000
# Processing epoch 398/2000
# Processing epoch 399/2000
# Processing epoch 400/2000
# Processing epoch 401/2000
#
# Epoch 401 completed
# Critic loss (average): -0.4568448139677639
# Generator loss (average): -1.0503482721599018
#
# EMD (average): 0.005609453358654493
# ACF RMSE (average): 0.04290212756793395
# VOLATILITY RMSE (average): 0.25766067284947203
# LEVERAGE RMSE (average): 0.0849438825257476
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.030610296057305503 0.03212379887126371
# Min-Max values after Lambert:  -2.3386192790870486 2.4141288614647434
#
# Processing epoch 402/2000
# Processing epoch 403/2000
# Processing epoch 404/2000
# Processing epoch 405/2000
# Processing epoch 406/2000
# Processing epoch 407/2000
# Processing epoch 408/2000
# Processing epoch 409/2000
# Processing epoch 410/2000
# Processing epoch 411/2000
# Processing epoch 412/2000
# Processing epoch 413/2000
# Processing epoch 414/2000
# Processing epoch 415/2000
# Processing epoch 416/2000
# Processing epoch 417/2000
# Processing epoch 418/2000
# Processing epoch 419/2000
# Processing epoch 420/2000
# Processing epoch 421/2000
# Processing epoch 422/2000
# Processing epoch 423/2000
# Processing epoch 424/2000
# Processing epoch 425/2000
# Processing epoch 426/2000
# Processing epoch 427/2000
# Processing epoch 428/2000
# Processing epoch 429/2000
# Processing epoch 430/2000
# Processing epoch 431/2000
# Processing epoch 432/2000
# Processing epoch 433/2000
# Processing epoch 434/2000
# Processing epoch 435/2000
# Processing epoch 436/2000
# Processing epoch 437/2000
# Processing epoch 438/2000
# Processing epoch 439/2000
# Processing epoch 440/2000
# Processing epoch 441/2000
# Processing epoch 442/2000
# Processing epoch 443/2000
# Processing epoch 444/2000
# Processing epoch 445/2000
# Processing epoch 446/2000
# Processing epoch 447/2000
# Processing epoch 448/2000
# Processing epoch 449/2000
# Processing epoch 450/2000
# Processing epoch 451/2000
# Processing epoch 452/2000
# Processing epoch 453/2000
# Processing epoch 454/2000
# Processing epoch 455/2000
# Processing epoch 456/2000
# Processing epoch 457/2000
# Processing epoch 458/2000
# Processing epoch 459/2000
# Processing epoch 460/2000
# Processing epoch 461/2000
# Processing epoch 462/2000
# Processing epoch 463/2000
# Processing epoch 464/2000
# Processing epoch 465/2000
# Processing epoch 466/2000
# Processing epoch 467/2000
# Processing epoch 468/2000
# Processing epoch 469/2000
# Processing epoch 470/2000
# Processing epoch 471/2000
# Processing epoch 472/2000
# Processing epoch 473/2000
# Processing epoch 474/2000
# Processing epoch 475/2000
# Processing epoch 476/2000
# Processing epoch 477/2000
# Processing epoch 478/2000
# Processing epoch 479/2000
# Processing epoch 480/2000
# Processing epoch 481/2000
# Processing epoch 482/2000
# Processing epoch 483/2000
# Processing epoch 484/2000
# Processing epoch 485/2000
# Processing epoch 486/2000
# Processing epoch 487/2000
# Processing epoch 488/2000
# Processing epoch 489/2000
# Processing epoch 490/2000
# Processing epoch 491/2000
# Processing epoch 492/2000
# Processing epoch 493/2000
# Processing epoch 494/2000
# Processing epoch 495/2000
# Processing epoch 496/2000
# Processing epoch 497/2000
# Processing epoch 498/2000
# Processing epoch 499/2000
# Processing epoch 500/2000
# Processing epoch 501/2000
#
# Epoch 501 completed
# Critic loss (average): -0.44199006037233723
# Generator loss (average): -0.930400113377339
#
# EMD (average): 0.008355156603307594
# ACF RMSE (average): 0.04672293745542364
# VOLATILITY RMSE (average): 0.30601446855792863
# LEVERAGE RMSE (average): 0.08817270198276404
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.053279734373605656 0.035817821949132
# Min-Max values after Lambert:  -4.056060662880459 2.6939888217380927
#
# Processing epoch 502/2000
# Processing epoch 503/2000
# Processing epoch 504/2000
# Processing epoch 505/2000
# Processing epoch 506/2000
# Processing epoch 507/2000
# Processing epoch 508/2000
# Processing epoch 509/2000
# Processing epoch 510/2000
# Processing epoch 511/2000
# Processing epoch 512/2000
# Processing epoch 513/2000
# Processing epoch 514/2000
# Processing epoch 515/2000
# Processing epoch 516/2000
# Processing epoch 517/2000
# Processing epoch 518/2000
# Processing epoch 519/2000
# Processing epoch 520/2000
# Processing epoch 521/2000
# Processing epoch 522/2000
# Processing epoch 523/2000
# Processing epoch 524/2000
# Processing epoch 525/2000
# Processing epoch 526/2000
# Processing epoch 527/2000
# Processing epoch 528/2000
# Processing epoch 529/2000
# Processing epoch 530/2000
# Processing epoch 531/2000
# Processing epoch 532/2000
# Processing epoch 533/2000
# Processing epoch 534/2000
# Processing epoch 535/2000
# Processing epoch 536/2000
# Processing epoch 537/2000
# Processing epoch 538/2000
# Processing epoch 539/2000
# Processing epoch 540/2000
# Processing epoch 541/2000
# Processing epoch 542/2000
# Processing epoch 543/2000
# Processing epoch 544/2000
# Processing epoch 545/2000
# Processing epoch 546/2000
# Processing epoch 547/2000
# Processing epoch 548/2000
# Processing epoch 549/2000
# Processing epoch 550/2000
# Processing epoch 551/2000
# Processing epoch 552/2000
# Processing epoch 553/2000
# Processing epoch 554/2000
# Processing epoch 555/2000
# Processing epoch 556/2000
# Processing epoch 557/2000
# Processing epoch 558/2000
# Processing epoch 559/2000
# Processing epoch 560/2000
# Processing epoch 561/2000
# Processing epoch 562/2000
# Processing epoch 563/2000
# Processing epoch 564/2000
# Processing epoch 565/2000
# Processing epoch 566/2000
# Processing epoch 567/2000
# Processing epoch 568/2000
# Processing epoch 569/2000
# Processing epoch 570/2000
# Processing epoch 571/2000
# Processing epoch 572/2000
# Processing epoch 573/2000
# Processing epoch 574/2000
# Processing epoch 575/2000
# Processing epoch 576/2000
# Processing epoch 577/2000
# Processing epoch 578/2000
# Processing epoch 579/2000
# Processing epoch 580/2000
# Processing epoch 581/2000
# Processing epoch 582/2000
# Processing epoch 583/2000
# Processing epoch 584/2000
# Processing epoch 585/2000
# Processing epoch 586/2000
# Processing epoch 587/2000
# Processing epoch 588/2000
# Processing epoch 589/2000
# Processing epoch 590/2000
# Processing epoch 591/2000
# Processing epoch 592/2000
# Processing epoch 593/2000
# Processing epoch 594/2000
# Processing epoch 595/2000
# Processing epoch 596/2000
# Processing epoch 597/2000
# Processing epoch 598/2000
# Processing epoch 599/2000
# Processing epoch 600/2000
# Processing epoch 601/2000
#
# Epoch 601 completed
# Critic loss (average): -0.1631669285055095
# Generator loss (average): -1.0728558730193298
#
# EMD (average): 0.007924667659801916
# ACF RMSE (average): 0.04388715587528642
# VOLATILITY RMSE (average): 0.2857769210062181
# LEVERAGE RMSE (average): 0.07910189925581085
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.03294289323819193 0.03529962157587883
# Min-Max values after Lambert:  -2.5153373289248195 2.654729853178547
#
# Processing epoch 602/2000
# Processing epoch 603/2000
# Processing epoch 604/2000
# Processing epoch 605/2000
# Processing epoch 606/2000
# Processing epoch 607/2000
# Processing epoch 608/2000
# Processing epoch 609/2000
# Processing epoch 610/2000
# Processing epoch 611/2000
# Processing epoch 612/2000
# Processing epoch 613/2000
# Processing epoch 614/2000
# Processing epoch 615/2000
# Processing epoch 616/2000
# Processing epoch 617/2000
# Processing epoch 618/2000
# Processing epoch 619/2000
# Processing epoch 620/2000
# Processing epoch 621/2000
# Processing epoch 622/2000
# Processing epoch 623/2000
# Processing epoch 624/2000
# Processing epoch 625/2000
# Processing epoch 626/2000
# Processing epoch 627/2000
# Processing epoch 628/2000
# Processing epoch 629/2000
# Processing epoch 630/2000
# Processing epoch 631/2000
# Processing epoch 632/2000
# Processing epoch 633/2000
# Processing epoch 634/2000
# Processing epoch 635/2000
# Processing epoch 636/2000
# Processing epoch 637/2000
# Processing epoch 638/2000
# Processing epoch 639/2000
# Processing epoch 640/2000
# Processing epoch 641/2000
# Processing epoch 642/2000
# Processing epoch 643/2000
# Processing epoch 644/2000
# Processing epoch 645/2000
# Processing epoch 646/2000
# Processing epoch 647/2000
# Processing epoch 648/2000
# Processing epoch 649/2000
# Processing epoch 650/2000
# Processing epoch 651/2000
# Processing epoch 652/2000
# Processing epoch 653/2000
# Processing epoch 654/2000
# Processing epoch 655/2000
# Processing epoch 656/2000
# Processing epoch 657/2000
# Processing epoch 658/2000
# Processing epoch 659/2000
# Processing epoch 660/2000
# Processing epoch 661/2000
# Processing epoch 662/2000
# Processing epoch 663/2000
# Processing epoch 664/2000
# Processing epoch 665/2000
# Processing epoch 666/2000
# Processing epoch 667/2000
# Processing epoch 668/2000
# Processing epoch 669/2000
# Processing epoch 670/2000
# Processing epoch 671/2000
# Processing epoch 672/2000
# Processing epoch 673/2000
# Processing epoch 674/2000
# Processing epoch 675/2000
# Processing epoch 676/2000
# Processing epoch 677/2000
# Processing epoch 678/2000
# Processing epoch 679/2000
# Processing epoch 680/2000
# Processing epoch 681/2000
# Processing epoch 682/2000
# Processing epoch 683/2000
# Processing epoch 684/2000
# Processing epoch 685/2000
# Processing epoch 686/2000
# Processing epoch 687/2000
# Processing epoch 688/2000
# Processing epoch 689/2000
# Processing epoch 690/2000
# Processing epoch 691/2000
# Processing epoch 692/2000
# Processing epoch 693/2000
# Processing epoch 694/2000
# Processing epoch 695/2000
# Processing epoch 696/2000
# Processing epoch 697/2000
# Processing epoch 698/2000
# Processing epoch 699/2000
# Processing epoch 700/2000
# Processing epoch 701/2000
#
# Epoch 701 completed
# Critic loss (average): -0.33132113820667464
# Generator loss (average): -1.4027636209825791
#
# EMD (average): 0.0076085379305639265
# ACF RMSE (average): 0.05682719086544066
# VOLATILITY RMSE (average): 0.25709374166516075
# LEVERAGE RMSE (average): 0.08952107597980105
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.03294289323819193 0.03306663412894599
# Min-Max values after Lambert:  -2.5153373289248195 2.4855582575993074
#
# Processing epoch 702/2000
# Processing epoch 703/2000
# Processing epoch 704/2000
# Processing epoch 705/2000
# Processing epoch 706/2000
# Processing epoch 707/2000
# Processing epoch 708/2000
# Processing epoch 709/2000
# Processing epoch 710/2000
# Processing epoch 711/2000
# Processing epoch 712/2000
# Processing epoch 713/2000
# Processing epoch 714/2000
# Processing epoch 715/2000
# Processing epoch 716/2000
# Processing epoch 717/2000
# Processing epoch 718/2000
# Processing epoch 719/2000
# Processing epoch 720/2000
# Processing epoch 721/2000
# Processing epoch 722/2000
# Processing epoch 723/2000
# Processing epoch 724/2000
# Processing epoch 725/2000
# Processing epoch 726/2000
# Processing epoch 727/2000
# Processing epoch 728/2000
# Processing epoch 729/2000
# Processing epoch 730/2000
# Processing epoch 731/2000
# Processing epoch 732/2000
# Processing epoch 733/2000
# Processing epoch 734/2000
# Processing epoch 735/2000
# Processing epoch 736/2000
# Processing epoch 737/2000
# Processing epoch 738/2000
# Processing epoch 739/2000
# Processing epoch 740/2000
# Processing epoch 741/2000
# Processing epoch 742/2000
# Processing epoch 743/2000
# Processing epoch 744/2000
# Processing epoch 745/2000
# Processing epoch 746/2000
# Processing epoch 747/2000
# Processing epoch 748/2000
# Processing epoch 749/2000
# Processing epoch 750/2000
# Processing epoch 751/2000
# Processing epoch 752/2000
# Processing epoch 753/2000
# Processing epoch 754/2000
# Processing epoch 755/2000
# Processing epoch 756/2000
# Processing epoch 757/2000
# Processing epoch 758/2000
# Processing epoch 759/2000
# Processing epoch 760/2000
# Processing epoch 761/2000
# Processing epoch 762/2000
# Processing epoch 763/2000
# Processing epoch 764/2000
# Processing epoch 765/2000
# Processing epoch 766/2000
# Processing epoch 767/2000
# Processing epoch 768/2000
# Processing epoch 769/2000
# Processing epoch 770/2000
# Processing epoch 771/2000
# Processing epoch 772/2000
# Processing epoch 773/2000
# Processing epoch 774/2000
# Processing epoch 775/2000
# Processing epoch 776/2000
# Processing epoch 777/2000
# Processing epoch 778/2000
# Processing epoch 779/2000
# Processing epoch 780/2000
# Processing epoch 781/2000
# Processing epoch 782/2000
# Processing epoch 783/2000
# Processing epoch 784/2000
# Processing epoch 785/2000
# Processing epoch 786/2000
# Processing epoch 787/2000
# Processing epoch 788/2000
# Processing epoch 789/2000
# Processing epoch 790/2000
# Processing epoch 791/2000
# Processing epoch 792/2000
# Processing epoch 793/2000
# Processing epoch 794/2000
# Processing epoch 795/2000
# Processing epoch 796/2000
# Processing epoch 797/2000
# Processing epoch 798/2000
# Processing epoch 799/2000
# Processing epoch 800/2000
# Processing epoch 801/2000
#
# Epoch 801 completed
# Critic loss (average): -0.15336458197101693
# Generator loss (average): -0.9823441530256785
#
# EMD (average): 0.007624646053424592
# ACF RMSE (average): 0.048218376822226086
# VOLATILITY RMSE (average): 0.29902577963259336
# LEVERAGE RMSE (average): 0.08505066987548492
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.03494548116173065 0.024473645075796427
# Min-Max values after Lambert:  -2.6670538084679984 1.8345516113626732
#
# Processing epoch 802/2000
# Processing epoch 803/2000
# Processing epoch 804/2000
# Processing epoch 805/2000
# Processing epoch 806/2000
# Processing epoch 807/2000
# Processing epoch 808/2000
# Processing epoch 809/2000
# Processing epoch 810/2000
# Processing epoch 811/2000
# Processing epoch 812/2000
# Processing epoch 813/2000
# Processing epoch 814/2000
# Processing epoch 815/2000
# Processing epoch 816/2000
# Processing epoch 817/2000
# Processing epoch 818/2000
# Processing epoch 819/2000
# Processing epoch 820/2000
# Processing epoch 821/2000
# Processing epoch 822/2000
# Processing epoch 823/2000
# Processing epoch 824/2000
# Processing epoch 825/2000
# Processing epoch 826/2000
# Processing epoch 827/2000
# Processing epoch 828/2000
# Processing epoch 829/2000
# Processing epoch 830/2000
# Processing epoch 831/2000
# Processing epoch 832/2000
# Processing epoch 833/2000
# Processing epoch 834/2000
# Processing epoch 835/2000
# Processing epoch 836/2000
# Processing epoch 837/2000
# Processing epoch 838/2000
# Processing epoch 839/2000
# Processing epoch 840/2000
# Processing epoch 841/2000
# Processing epoch 842/2000
# Processing epoch 843/2000
# Processing epoch 844/2000
# Processing epoch 845/2000
# Processing epoch 846/2000
# Processing epoch 847/2000
# Processing epoch 848/2000
# Processing epoch 849/2000
# Processing epoch 850/2000
# Processing epoch 851/2000
# Processing epoch 852/2000
# Processing epoch 853/2000
# Processing epoch 854/2000
# Processing epoch 855/2000
# Processing epoch 856/2000
# Processing epoch 857/2000
# Processing epoch 858/2000
# Processing epoch 859/2000
# Processing epoch 860/2000
# Processing epoch 861/2000
# Processing epoch 862/2000
# Processing epoch 863/2000
# Processing epoch 864/2000
# Processing epoch 865/2000
# Processing epoch 866/2000
# Processing epoch 867/2000
# Processing epoch 868/2000
# Processing epoch 869/2000
# Processing epoch 870/2000
# Processing epoch 871/2000
# Processing epoch 872/2000
# Processing epoch 873/2000
# Processing epoch 874/2000
# Processing epoch 875/2000
# Processing epoch 876/2000
# Processing epoch 877/2000
# Processing epoch 878/2000
# Processing epoch 879/2000
# Processing epoch 880/2000
# Processing epoch 881/2000
# Processing epoch 882/2000
# Processing epoch 883/2000
# Processing epoch 884/2000
# Processing epoch 885/2000
# Processing epoch 886/2000
# Processing epoch 887/2000
# Processing epoch 888/2000
# Processing epoch 889/2000
# Processing epoch 890/2000
# Processing epoch 891/2000
# Processing epoch 892/2000
# Processing epoch 893/2000
# Processing epoch 894/2000
# Processing epoch 895/2000
# Processing epoch 896/2000
# Processing epoch 897/2000
# Processing epoch 898/2000
# Processing epoch 899/2000
# Processing epoch 900/2000
# Processing epoch 901/2000
#
# Epoch 901 completed
# Critic loss (average): -0.25891768516292757
# Generator loss (average): -1.1200833823581875
#
# EMD (average): 0.008252305627892687
# ACF RMSE (average): 0.04654692324419019
# VOLATILITY RMSE (average): 0.293961706442151
# LEVERAGE RMSE (average): 0.08755843948583084
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.02951023860419791 0.030106731929050938
# Min-Max values after Lambert:  -2.2552786965742966 2.2613154484413176
#
# Processing epoch 902/2000
# Processing epoch 903/2000
# Processing epoch 904/2000
# Processing epoch 905/2000
# Processing epoch 906/2000
# Processing epoch 907/2000
# Processing epoch 908/2000
# Processing epoch 909/2000
# Processing epoch 910/2000
# Processing epoch 911/2000
# Processing epoch 912/2000
# Processing epoch 913/2000
# Processing epoch 914/2000
# Processing epoch 915/2000
# Processing epoch 916/2000
# Processing epoch 917/2000
# Processing epoch 918/2000
# Processing epoch 919/2000
# Processing epoch 920/2000
# Processing epoch 921/2000
# Processing epoch 922/2000
# Processing epoch 923/2000
# Processing epoch 924/2000
# Processing epoch 925/2000
# Processing epoch 926/2000
# Processing epoch 927/2000
# Processing epoch 928/2000
# Processing epoch 929/2000
# Processing epoch 930/2000
# Processing epoch 931/2000
# Processing epoch 932/2000
# Processing epoch 933/2000
# Processing epoch 934/2000
# Processing epoch 935/2000
# Processing epoch 936/2000
# Processing epoch 937/2000
# Processing epoch 938/2000
# Processing epoch 939/2000
# Processing epoch 940/2000
# Processing epoch 941/2000
# Processing epoch 942/2000
# Processing epoch 943/2000
# Processing epoch 944/2000
# Processing epoch 945/2000
# Processing epoch 946/2000
# Processing epoch 947/2000
# Processing epoch 948/2000
# Processing epoch 949/2000
# Processing epoch 950/2000
# Processing epoch 951/2000
# Processing epoch 952/2000
# Processing epoch 953/2000
# Processing epoch 954/2000
# Processing epoch 955/2000
# Processing epoch 956/2000
# Processing epoch 957/2000
# Processing epoch 958/2000
# Processing epoch 959/2000
# Processing epoch 960/2000
# Processing epoch 961/2000
# Processing epoch 962/2000
# Processing epoch 963/2000
# Processing epoch 964/2000
# Processing epoch 965/2000
# Processing epoch 966/2000
# Processing epoch 967/2000
# Processing epoch 968/2000
# Processing epoch 969/2000
# Processing epoch 970/2000
# Processing epoch 971/2000
# Processing epoch 972/2000
# Processing epoch 973/2000
# Processing epoch 974/2000
# Processing epoch 975/2000
# Processing epoch 976/2000
# Processing epoch 977/2000
# Processing epoch 978/2000
# Processing epoch 979/2000
# Processing epoch 980/2000
# Processing epoch 981/2000
# Processing epoch 982/2000
# Processing epoch 983/2000
# Processing epoch 984/2000
# Processing epoch 985/2000
# Processing epoch 986/2000
# Processing epoch 987/2000
# Processing epoch 988/2000
# Processing epoch 989/2000
# Processing epoch 990/2000
# Processing epoch 991/2000
# Processing epoch 992/2000
# Processing epoch 993/2000
# Processing epoch 994/2000
# Processing epoch 995/2000
# Processing epoch 996/2000
# Processing epoch 997/2000
# Processing epoch 998/2000
# Processing epoch 999/2000
# Processing epoch 1000/2000
# Processing epoch 1001/2000
#
# Epoch 1001 completed
# Critic loss (average): -0.3525418496624603
# Generator loss (average): -1.167753526748572
#
# EMD (average): 0.0076830060156703
# ACF RMSE (average): 0.040330016167948124
# VOLATILITY RMSE (average): 0.26905895976773464
# LEVERAGE RMSE (average): 0.09100476861796679
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.0312910756125523 0.028023477369460866
# Min-Max values after Lambert:  -2.390195280446581 2.1034876476949846
#
# Processing epoch 1002/2000
# Processing epoch 1003/2000
# Processing epoch 1004/2000
# Processing epoch 1005/2000
# Processing epoch 1006/2000
# Processing epoch 1007/2000
# Processing epoch 1008/2000
# Processing epoch 1009/2000
# Processing epoch 1010/2000
# Processing epoch 1011/2000
# Processing epoch 1012/2000
# Processing epoch 1013/2000
# Processing epoch 1014/2000
# Processing epoch 1015/2000
# Processing epoch 1016/2000
# Processing epoch 1017/2000
# Processing epoch 1018/2000
# Processing epoch 1019/2000
# Processing epoch 1020/2000
# Processing epoch 1021/2000
# Processing epoch 1022/2000
# Processing epoch 1023/2000
# Processing epoch 1024/2000
# Processing epoch 1025/2000
# Processing epoch 1026/2000
# Processing epoch 1027/2000
# Processing epoch 1028/2000
# Processing epoch 1029/2000
# Processing epoch 1030/2000
# Processing epoch 1031/2000
# Processing epoch 1032/2000
# Processing epoch 1033/2000
# Processing epoch 1034/2000
# Processing epoch 1035/2000
# Processing epoch 1036/2000
# Processing epoch 1037/2000
# Processing epoch 1038/2000
# Processing epoch 1039/2000
# Processing epoch 1040/2000
# Processing epoch 1041/2000
# Processing epoch 1042/2000
# Processing epoch 1043/2000
# Processing epoch 1044/2000
# Processing epoch 1045/2000
# Processing epoch 1046/2000
# Processing epoch 1047/2000
# Processing epoch 1048/2000
# Processing epoch 1049/2000
# Processing epoch 1050/2000
# Processing epoch 1051/2000
# Processing epoch 1052/2000
# Processing epoch 1053/2000
# Processing epoch 1054/2000
# Processing epoch 1055/2000
# Processing epoch 1056/2000
# Processing epoch 1057/2000
# Processing epoch 1058/2000
# Processing epoch 1059/2000
# Processing epoch 1060/2000
# Processing epoch 1061/2000
# Processing epoch 1062/2000
# Processing epoch 1063/2000
# Processing epoch 1064/2000
# Processing epoch 1065/2000
# Processing epoch 1066/2000
# Processing epoch 1067/2000
# Processing epoch 1068/2000
# Processing epoch 1069/2000
# Processing epoch 1070/2000
# Processing epoch 1071/2000
# Processing epoch 1072/2000
# Processing epoch 1073/2000
# Processing epoch 1074/2000
# Processing epoch 1075/2000
# Processing epoch 1076/2000
# Processing epoch 1077/2000
# Processing epoch 1078/2000
# Processing epoch 1079/2000
# Processing epoch 1080/2000
# Processing epoch 1081/2000
# Processing epoch 1082/2000
# Processing epoch 1083/2000
# Processing epoch 1084/2000
# Processing epoch 1085/2000
# Processing epoch 1086/2000
# Processing epoch 1087/2000
# Processing epoch 1088/2000
# Processing epoch 1089/2000
# Processing epoch 1090/2000
# Processing epoch 1091/2000
# Processing epoch 1092/2000
# Processing epoch 1093/2000
# Processing epoch 1094/2000
# Processing epoch 1095/2000
# Processing epoch 1096/2000
# Processing epoch 1097/2000
# Processing epoch 1098/2000
# Processing epoch 1099/2000
# Processing epoch 1100/2000
# Processing epoch 1101/2000
#
# Epoch 1101 completed
# Critic loss (average): -0.468950133095401
# Generator loss (average): -1.0012961751342957
#
# EMD (average): 0.006989367388016421
# ACF RMSE (average): 0.05484182887330404
# VOLATILITY RMSE (average): 0.24290585990031624
# LEVERAGE RMSE (average): 0.0781022351152128
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.047507169476953603 0.04337170489886407
# Min-Max values after Lambert:  -3.618729940089026 3.266272572450742
#
# Processing epoch 1102/2000
# Processing epoch 1103/2000
# Processing epoch 1104/2000
# Processing epoch 1105/2000
# Processing epoch 1106/2000
# Processing epoch 1107/2000
# Processing epoch 1108/2000
# Processing epoch 1109/2000
# Processing epoch 1110/2000
# Processing epoch 1111/2000
# Processing epoch 1112/2000
# Processing epoch 1113/2000
# Processing epoch 1114/2000
# Processing epoch 1115/2000
# Processing epoch 1116/2000
# Processing epoch 1117/2000
# Processing epoch 1118/2000
# Processing epoch 1119/2000
# Processing epoch 1120/2000
# Processing epoch 1121/2000
# Processing epoch 1122/2000
# Processing epoch 1123/2000
# Processing epoch 1124/2000
# Processing epoch 1125/2000
# Processing epoch 1126/2000
# Processing epoch 1127/2000
# Processing epoch 1128/2000
# Processing epoch 1129/2000
# Processing epoch 1130/2000
# Processing epoch 1131/2000
# Processing epoch 1132/2000
# Processing epoch 1133/2000
# Processing epoch 1134/2000
# Processing epoch 1135/2000
# Processing epoch 1136/2000
# Processing epoch 1137/2000
# Processing epoch 1138/2000
# Processing epoch 1139/2000
# Processing epoch 1140/2000
# Processing epoch 1141/2000
# Processing epoch 1142/2000
# Processing epoch 1143/2000
# Processing epoch 1144/2000
# Processing epoch 1145/2000
# Processing epoch 1146/2000
# Processing epoch 1147/2000
# Processing epoch 1148/2000
# Processing epoch 1149/2000
# Processing epoch 1150/2000
# Processing epoch 1151/2000
# Processing epoch 1152/2000
# Processing epoch 1153/2000
# Processing epoch 1154/2000
# Processing epoch 1155/2000
# Processing epoch 1156/2000
# Processing epoch 1157/2000
# Processing epoch 1158/2000
# Processing epoch 1159/2000
# Processing epoch 1160/2000
# Processing epoch 1161/2000
# Processing epoch 1162/2000
# Processing epoch 1163/2000
# Processing epoch 1164/2000
# Processing epoch 1165/2000
# Processing epoch 1166/2000
# Processing epoch 1167/2000
# Processing epoch 1168/2000
# Processing epoch 1169/2000
# Processing epoch 1170/2000
# Processing epoch 1171/2000
# Processing epoch 1172/2000
# Processing epoch 1173/2000
# Processing epoch 1174/2000
# Processing epoch 1175/2000
# Processing epoch 1176/2000
# Processing epoch 1177/2000
# Processing epoch 1178/2000
# Processing epoch 1179/2000
# Processing epoch 1180/2000
# Processing epoch 1181/2000
# Processing epoch 1182/2000
# Processing epoch 1183/2000
# Processing epoch 1184/2000
# Processing epoch 1185/2000
# Processing epoch 1186/2000
# Processing epoch 1187/2000
# Processing epoch 1188/2000
# Processing epoch 1189/2000
# Processing epoch 1190/2000
# Processing epoch 1191/2000
# Processing epoch 1192/2000
# Processing epoch 1193/2000
# Processing epoch 1194/2000
# Processing epoch 1195/2000
# Processing epoch 1196/2000
# Processing epoch 1197/2000
# Processing epoch 1198/2000
# Processing epoch 1199/2000
# Processing epoch 1200/2000
# Processing epoch 1201/2000
#
# Epoch 1201 completed
# Critic loss (average): -0.43957285734497625
# Generator loss (average): -0.8787875434584267
#
# EMD (average): 0.0069650715853395075
# ACF RMSE (average): 0.03360269315466857
# VOLATILITY RMSE (average): 0.26093401117884824
# LEVERAGE RMSE (average): 0.08924412333655227
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.028039502199228468 0.02863183638090856
# Min-Max values after Lambert:  -2.1438553992123213 2.149577053523476
#
# Processing epoch 1202/2000
# Processing epoch 1203/2000
# Processing epoch 1204/2000
# Processing epoch 1205/2000
# Processing epoch 1206/2000
# Processing epoch 1207/2000
# Processing epoch 1208/2000
# Processing epoch 1209/2000
# Processing epoch 1210/2000
# Processing epoch 1211/2000
# Processing epoch 1212/2000
# Processing epoch 1213/2000
# Processing epoch 1214/2000
# Processing epoch 1215/2000
# Processing epoch 1216/2000
# Processing epoch 1217/2000
# Processing epoch 1218/2000
# Processing epoch 1219/2000
# Processing epoch 1220/2000
# Processing epoch 1221/2000
# Processing epoch 1222/2000
# Processing epoch 1223/2000
# Processing epoch 1224/2000
# Processing epoch 1225/2000
# Processing epoch 1226/2000
# Processing epoch 1227/2000
# Processing epoch 1228/2000
# Processing epoch 1229/2000
# Processing epoch 1230/2000
# Processing epoch 1231/2000
# Processing epoch 1232/2000
# Processing epoch 1233/2000
# Processing epoch 1234/2000
# Processing epoch 1235/2000
# Processing epoch 1236/2000
# Processing epoch 1237/2000
# Processing epoch 1238/2000
# Processing epoch 1239/2000
# Processing epoch 1240/2000
# Processing epoch 1241/2000
# Processing epoch 1242/2000
# Processing epoch 1243/2000
# Processing epoch 1244/2000
# Processing epoch 1245/2000
# Processing epoch 1246/2000
# Processing epoch 1247/2000
# Processing epoch 1248/2000
# Processing epoch 1249/2000
# Processing epoch 1250/2000
# Processing epoch 1251/2000
# Processing epoch 1252/2000
# Processing epoch 1253/2000
# Processing epoch 1254/2000
# Processing epoch 1255/2000
# Processing epoch 1256/2000
# Processing epoch 1257/2000
# Processing epoch 1258/2000
# Processing epoch 1259/2000
# Processing epoch 1260/2000
# Processing epoch 1261/2000
# Processing epoch 1262/2000
# Processing epoch 1263/2000
# Processing epoch 1264/2000
# Processing epoch 1265/2000
# Processing epoch 1266/2000
# Processing epoch 1267/2000
# Processing epoch 1268/2000
# Processing epoch 1269/2000
# Processing epoch 1270/2000
# Processing epoch 1271/2000
# Processing epoch 1272/2000
# Processing epoch 1273/2000
# Processing epoch 1274/2000
# Processing epoch 1275/2000
# Processing epoch 1276/2000
# Processing epoch 1277/2000
# Processing epoch 1278/2000
# Processing epoch 1279/2000
# Processing epoch 1280/2000
# Processing epoch 1281/2000
# Processing epoch 1282/2000
# Processing epoch 1283/2000
# Processing epoch 1284/2000
# Processing epoch 1285/2000
# Processing epoch 1286/2000
# Processing epoch 1287/2000
# Processing epoch 1288/2000
# Processing epoch 1289/2000
# Processing epoch 1290/2000
# Processing epoch 1291/2000
# Processing epoch 1292/2000
# Processing epoch 1293/2000
# Processing epoch 1294/2000
# Processing epoch 1295/2000
# Processing epoch 1296/2000
# Processing epoch 1297/2000
# Processing epoch 1298/2000
# Processing epoch 1299/2000
# Processing epoch 1300/2000
# Processing epoch 1301/2000
# Epoch 1301 completed
# Critic loss (average): -0.4520589468013243
# Generator loss (average): -0.6939685085641679
#
# EMD (average): 0.007084242127887012
# ACF RMSE (average): 0.050495951389773086
# VOLATILITY RMSE (average): 0.26015857217854743
# LEVERAGE RMSE (average): 0.07718527574618302
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.033431742264705085 0.02782375335195159
# Min-Max values after Lambert:  -2.5523726333221552 2.0883565143946385
#
# Processing epoch 1302/2000
# Processing epoch 1303/2000
# Processing epoch 1304/2000
# Processing epoch 1305/2000
# Processing epoch 1306/2000
# Processing epoch 1307/2000
# Processing epoch 1308/2000
# Processing epoch 1309/2000
# Processing epoch 1310/2000
# Processing epoch 1311/2000
# Processing epoch 1312/2000
# Processing epoch 1313/2000
# Processing epoch 1314/2000
# Processing epoch 1315/2000
# Processing epoch 1316/2000
# Processing epoch 1317/2000
# Processing epoch 1318/2000
# Processing epoch 1319/2000
# Processing epoch 1320/2000
# Processing epoch 1321/2000
# Processing epoch 1322/2000
# Processing epoch 1323/2000
# Processing epoch 1324/2000
# Processing epoch 1325/2000
# Processing epoch 1326/2000
# Processing epoch 1327/2000
# Processing epoch 1328/2000
# Processing epoch 1329/2000
# Processing epoch 1330/2000
# Processing epoch 1331/2000
# Processing epoch 1332/2000
# Processing epoch 1333/2000
# Processing epoch 1334/2000
# Processing epoch 1335/2000
# Processing epoch 1336/2000
# Processing epoch 1337/2000
# Processing epoch 1338/2000
# Processing epoch 1339/2000
# Processing epoch 1340/2000
# Processing epoch 1341/2000
# Processing epoch 1342/2000
# Processing epoch 1343/2000
# Processing epoch 1344/2000
# Processing epoch 1345/2000
# Processing epoch 1346/2000
# Processing epoch 1347/2000
# Processing epoch 1348/2000
# Processing epoch 1349/2000
# Processing epoch 1350/2000
# Processing epoch 1351/2000
# Processing epoch 1352/2000
# Processing epoch 1353/2000
# Processing epoch 1354/2000
# Processing epoch 1355/2000
# Processing epoch 1356/2000
# Processing epoch 1357/2000
# Processing epoch 1358/2000
# Processing epoch 1359/2000
# Processing epoch 1360/2000
# Processing epoch 1361/2000
# Processing epoch 1362/2000
# Processing epoch 1363/2000
# Processing epoch 1364/2000
# Processing epoch 1365/2000
# Processing epoch 1366/2000
# Processing epoch 1367/2000
# Processing epoch 1368/2000
# Processing epoch 1369/2000
# Processing epoch 1370/2000
# Processing epoch 1371/2000
# Processing epoch 1372/2000
# Processing epoch 1373/2000
# Processing epoch 1374/2000
# Processing epoch 1375/2000
# Processing epoch 1376/2000
# Processing epoch 1377/2000
# Processing epoch 1378/2000
# Processing epoch 1379/2000
# Processing epoch 1380/2000
# Processing epoch 1381/2000
# Processing epoch 1382/2000
# Processing epoch 1383/2000
# Processing epoch 1384/2000
# Processing epoch 1385/2000
# Processing epoch 1386/2000
# Processing epoch 1387/2000
# Processing epoch 1388/2000
# Processing epoch 1389/2000
# Processing epoch 1390/2000
# Processing epoch 1391/2000
# Processing epoch 1392/2000
# Processing epoch 1393/2000
# Processing epoch 1394/2000
# Processing epoch 1395/2000
# Processing epoch 1396/2000
# Processing epoch 1397/2000
# Processing epoch 1398/2000
# Processing epoch 1399/2000
# Processing epoch 1400/2000
# Processing epoch 1401/2000
#
# Epoch 1401 completed
# Critic loss (average): -0.18585448754637135
# Generator loss (average): -1.0798484404450461
#
# EMD (average): 0.00690641027098947
# ACF RMSE (average): 0.056023020412274194
# VOLATILITY RMSE (average): 0.25283812505298836
# LEVERAGE RMSE (average): 0.08573819566627854
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.03935530224257758 0.035557687645072486
# Min-Max values after Lambert:  -3.0011427750184136 2.6742809925055147
#
# Processing epoch 1402/2000
# Processing epoch 1403/2000
# Processing epoch 1404/2000
# Processing epoch 1405/2000
# Processing epoch 1406/2000
# Processing epoch 1407/2000
# Processing epoch 1408/2000
# Processing epoch 1409/2000
# Processing epoch 1410/2000
# Processing epoch 1411/2000
# Processing epoch 1412/2000
# Processing epoch 1413/2000
# Processing epoch 1414/2000
# Processing epoch 1415/2000
# Processing epoch 1416/2000
# Processing epoch 1417/2000
# Processing epoch 1418/2000
# Processing epoch 1419/2000
# Processing epoch 1420/2000
# Processing epoch 1421/2000
# Processing epoch 1422/2000
# Processing epoch 1423/2000
# Processing epoch 1424/2000
# Processing epoch 1425/2000
# Processing epoch 1426/2000
# Processing epoch 1427/2000
# Processing epoch 1428/2000
# Processing epoch 1429/2000
# Processing epoch 1430/2000
# Processing epoch 1431/2000
# Processing epoch 1432/2000
# Processing epoch 1433/2000
# Processing epoch 1434/2000
# Processing epoch 1435/2000
# Processing epoch 1436/2000
# Processing epoch 1437/2000
# Processing epoch 1438/2000
# Processing epoch 1439/2000
# Processing epoch 1440/2000
# Processing epoch 1441/2000
# Processing epoch 1442/2000
# Processing epoch 1443/2000
# Processing epoch 1444/2000
# Processing epoch 1445/2000
# Processing epoch 1446/2000
# Processing epoch 1447/2000
# Processing epoch 1448/2000
# Processing epoch 1449/2000
# Processing epoch 1450/2000
# Processing epoch 1451/2000
# Processing epoch 1452/2000
# Processing epoch 1453/2000
# Processing epoch 1454/2000
# Processing epoch 1455/2000
# Processing epoch 1456/2000
# Processing epoch 1457/2000
# Processing epoch 1458/2000
# Processing epoch 1459/2000
# Processing epoch 1460/2000
# Processing epoch 1461/2000
# Processing epoch 1462/2000
# Processing epoch 1463/2000
# Processing epoch 1464/2000
# Processing epoch 1465/2000
# Processing epoch 1466/2000
# Processing epoch 1467/2000
# Processing epoch 1468/2000
# Processing epoch 1469/2000
# Processing epoch 1470/2000
# Processing epoch 1471/2000
# Processing epoch 1472/2000
# Processing epoch 1473/2000
# Processing epoch 1474/2000
# Processing epoch 1475/2000
# Processing epoch 1476/2000
# Processing epoch 1477/2000
# Processing epoch 1478/2000
# Processing epoch 1479/2000
# Processing epoch 1480/2000
# Processing epoch 1481/2000
# Processing epoch 1482/2000
# Processing epoch 1483/2000
# Processing epoch 1484/2000
# Processing epoch 1485/2000
# Processing epoch 1486/2000
# Processing epoch 1487/2000
# Processing epoch 1488/2000
# Processing epoch 1489/2000
# Processing epoch 1490/2000
# Processing epoch 1491/2000
# Processing epoch 1492/2000
# Processing epoch 1493/2000
# Processing epoch 1494/2000
# Processing epoch 1495/2000
# Processing epoch 1496/2000
# Processing epoch 1497/2000
# Processing epoch 1498/2000
# Processing epoch 1499/2000
# Processing epoch 1500/2000
# Processing epoch 1501/2000
#
# Epoch 1501 completed
# Critic loss (average): -0.20626852271547674
# Generator loss (average): -1.0130882243122312
#
# EMD (average): 0.006721316906411974
# ACF RMSE (average): 0.04052667388849546
# VOLATILITY RMSE (average): 0.26037179647525227
# LEVERAGE RMSE (average): 0.09610224893211078
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.053279734373605656 0.04743903544752518
# Min-Max values after Lambert:  -4.056060662880459 3.574414384716774
#
# Processing epoch 1502/2000
# Processing epoch 1503/2000
# Processing epoch 1504/2000
# Processing epoch 1505/2000
# Processing epoch 1506/2000
# Processing epoch 1507/2000
# Processing epoch 1508/2000
# Processing epoch 1509/2000
# Processing epoch 1510/2000
# Processing epoch 1511/2000
# Processing epoch 1512/2000
# Processing epoch 1513/2000
# Processing epoch 1514/2000
# Processing epoch 1515/2000
# Processing epoch 1516/2000
# Processing epoch 1517/2000
# Processing epoch 1518/2000
# Processing epoch 1519/2000
# Processing epoch 1520/2000
# Processing epoch 1521/2000
# Processing epoch 1522/2000
# Processing epoch 1523/2000
# Processing epoch 1524/2000
# Processing epoch 1525/2000
# Processing epoch 1526/2000
# Processing epoch 1527/2000
# Processing epoch 1528/2000
# Processing epoch 1529/2000
# Processing epoch 1530/2000
# Processing epoch 1531/2000
# Processing epoch 1532/2000
# Processing epoch 1533/2000
# Processing epoch 1534/2000
# Processing epoch 1535/2000
# Processing epoch 1536/2000
# Processing epoch 1537/2000
# Processing epoch 1538/2000
# Processing epoch 1539/2000
# Processing epoch 1540/2000
# Processing epoch 1541/2000
# Processing epoch 1542/2000
# Processing epoch 1543/2000
# Processing epoch 1544/2000
# Processing epoch 1545/2000
# Processing epoch 1546/2000
# Processing epoch 1547/2000
# Processing epoch 1548/2000
# Processing epoch 1549/2000
# Processing epoch 1550/2000
# Processing epoch 1551/2000
# Processing epoch 1552/2000
# Processing epoch 1553/2000
# Processing epoch 1554/2000
# Processing epoch 1555/2000
# Processing epoch 1556/2000
# Processing epoch 1557/2000
# Processing epoch 1558/2000
# Processing epoch 1559/2000
# Processing epoch 1560/2000
# Processing epoch 1561/2000
# Processing epoch 1562/2000
# Processing epoch 1563/2000
# Processing epoch 1564/2000
# Processing epoch 1565/2000
# Processing epoch 1566/2000
# Processing epoch 1567/2000
# Processing epoch 1568/2000
# Processing epoch 1569/2000
# Processing epoch 1570/2000
# Processing epoch 1571/2000
# Processing epoch 1572/2000
# Processing epoch 1573/2000
# Processing epoch 1574/2000
# Processing epoch 1575/2000
# Processing epoch 1576/2000
# Processing epoch 1577/2000
# Processing epoch 1578/2000
# Processing epoch 1579/2000
# Processing epoch 1580/2000
# Processing epoch 1581/2000
# Processing epoch 1582/2000
# Processing epoch 1583/2000
# Processing epoch 1584/2000
# Processing epoch 1585/2000
# Processing epoch 1586/2000
# Processing epoch 1587/2000
# Processing epoch 1588/2000
# Processing epoch 1589/2000
# Processing epoch 1590/2000
# Processing epoch 1591/2000
# Processing epoch 1592/2000
# Processing epoch 1593/2000
# Processing epoch 1594/2000
# Processing epoch 1595/2000
# Processing epoch 1596/2000
# Processing epoch 1597/2000
# Processing epoch 1598/2000
# Processing epoch 1599/2000
# Processing epoch 1600/2000
# Processing epoch 1601/2000
#
# Epoch 1601 completed
# Critic loss (average): -0.22493913617357347
# Generator loss (average): -0.9118340686324322
#
# EMD (average): 0.006959601760351173
# ACF RMSE (average): 0.04442650269692964
# VOLATILITY RMSE (average): 0.27110703423332344
# LEVERAGE RMSE (average): 0.078806806926884
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.030835464611792134 0.024824108688951345
# Min-Max values after Lambert:  -2.3556780958256276 1.861102807927311
#
# Processing epoch 1602/2000
# Processing epoch 1603/2000
# Processing epoch 1604/2000
# Processing epoch 1605/2000
# Processing epoch 1606/2000
# Processing epoch 1607/2000
# Processing epoch 1608/2000
# Processing epoch 1609/2000
# Processing epoch 1610/2000
# Processing epoch 1611/2000
# Processing epoch 1612/2000
# Processing epoch 1613/2000
# Processing epoch 1614/2000
# Processing epoch 1615/2000
# Processing epoch 1616/2000
# Processing epoch 1617/2000
# Processing epoch 1618/2000
# Processing epoch 1619/2000
# Processing epoch 1620/2000
# Processing epoch 1621/2000
# Processing epoch 1622/2000
# Processing epoch 1623/2000
# Processing epoch 1624/2000
# Processing epoch 1625/2000
# Processing epoch 1626/2000
# Processing epoch 1627/2000
# Processing epoch 1628/2000
# Processing epoch 1629/2000
# Processing epoch 1630/2000
# Processing epoch 1631/2000
# Processing epoch 1632/2000
# Processing epoch 1633/2000
# Processing epoch 1634/2000
# Processing epoch 1635/2000
# Processing epoch 1636/2000
# Processing epoch 1637/2000
# Processing epoch 1638/2000
# Processing epoch 1639/2000
# Processing epoch 1640/2000
# Processing epoch 1641/2000
# Processing epoch 1642/2000
# Processing epoch 1643/2000
# Processing epoch 1644/2000
# Processing epoch 1645/2000
# Processing epoch 1646/2000
# Processing epoch 1647/2000
# Processing epoch 1648/2000
# Processing epoch 1649/2000
# Processing epoch 1650/2000
# Processing epoch 1651/2000
# Processing epoch 1652/2000
# Processing epoch 1653/2000
# Processing epoch 1654/2000
# Processing epoch 1655/2000
# Processing epoch 1656/2000
# Processing epoch 1657/2000
# Processing epoch 1658/2000
# Processing epoch 1659/2000
# Processing epoch 1660/2000
# Processing epoch 1661/2000
# Processing epoch 1662/2000
# Processing epoch 1663/2000
# Processing epoch 1664/2000
# Processing epoch 1665/2000
# Processing epoch 1666/2000
# Processing epoch 1667/2000
# Processing epoch 1668/2000
# Processing epoch 1669/2000
# Processing epoch 1670/2000
# Processing epoch 1671/2000
# Processing epoch 1672/2000
# Processing epoch 1673/2000
# Processing epoch 1674/2000
# Processing epoch 1675/2000
# Processing epoch 1676/2000
# Processing epoch 1677/2000
# Processing epoch 1678/2000
# Processing epoch 1679/2000
# Processing epoch 1680/2000
# Processing epoch 1681/2000
# Processing epoch 1682/2000
# Processing epoch 1683/2000
# Processing epoch 1684/2000
# Processing epoch 1685/2000
# Processing epoch 1686/2000
# Processing epoch 1687/2000
# Processing epoch 1688/2000
# Processing epoch 1689/2000
# Processing epoch 1690/2000
# Processing epoch 1691/2000
# Processing epoch 1692/2000
# Processing epoch 1693/2000
# Processing epoch 1694/2000
# Processing epoch 1695/2000
# Processing epoch 1696/2000
# Processing epoch 1697/2000
# Processing epoch 1698/2000
# Processing epoch 1699/2000
# Processing epoch 1700/2000
# Processing epoch 1701/2000
#
# Epoch 1701 completed
# Critic loss (average): -0.2005966224753164
# Generator loss (average): -0.7384101356304047
#
# EMD (average): 0.007241667330020346
# ACF RMSE (average): 0.03760289339647972
# VOLATILITY RMSE (average): 0.27667061076151706
# LEVERAGE RMSE (average): 0.09297412987818832
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.03906272191349174 0.032828154648843526
# Min-Max values after Lambert:  -2.978976828149999 2.4674910023546546
#
# Processing epoch 1702/2000
# Processing epoch 1703/2000
# Processing epoch 1704/2000
# Processing epoch 1705/2000
# Processing epoch 1706/2000
# Processing epoch 1707/2000
# Processing epoch 1708/2000
# Processing epoch 1709/2000
# Processing epoch 1710/2000
# Processing epoch 1711/2000
# Processing epoch 1712/2000
# Processing epoch 1713/2000
# Processing epoch 1714/2000
# Processing epoch 1715/2000
# Processing epoch 1716/2000
# Processing epoch 1717/2000
# Processing epoch 1718/2000
# Processing epoch 1719/2000
# Processing epoch 1720/2000
# Processing epoch 1721/2000
# Processing epoch 1722/2000
# Processing epoch 1723/2000
# Processing epoch 1724/2000
# Processing epoch 1725/2000
# Processing epoch 1726/2000
# Processing epoch 1727/2000
# Processing epoch 1728/2000
# Processing epoch 1729/2000
# Processing epoch 1730/2000
# Processing epoch 1731/2000
# Processing epoch 1732/2000
# Processing epoch 1733/2000
# Processing epoch 1734/2000
# Processing epoch 1735/2000
# Processing epoch 1736/2000
# Processing epoch 1737/2000
# Processing epoch 1738/2000
# Processing epoch 1739/2000
# Processing epoch 1740/2000
# Processing epoch 1741/2000
# Processing epoch 1742/2000
# Processing epoch 1743/2000
# Processing epoch 1744/2000
# Processing epoch 1745/2000
# Processing epoch 1746/2000
# Processing epoch 1747/2000
# Processing epoch 1748/2000
# Processing epoch 1749/2000
# Processing epoch 1750/2000
# Processing epoch 1751/2000
# Processing epoch 1752/2000
# Processing epoch 1753/2000
# Processing epoch 1754/2000
# Processing epoch 1755/2000
# Processing epoch 1756/2000
# Processing epoch 1757/2000
# Processing epoch 1758/2000
# Processing epoch 1759/2000
# Processing epoch 1760/2000
# Processing epoch 1761/2000
# Processing epoch 1762/2000
# Processing epoch 1763/2000
# Processing epoch 1764/2000
# Processing epoch 1765/2000
# Processing epoch 1766/2000
# Processing epoch 1767/2000
# Processing epoch 1768/2000
# Processing epoch 1769/2000
# Processing epoch 1770/2000
# Processing epoch 1771/2000
# Processing epoch 1772/2000
# Processing epoch 1773/2000
# Processing epoch 1774/2000
# Processing epoch 1775/2000
# Processing epoch 1776/2000
# Processing epoch 1777/2000
# Processing epoch 1778/2000
# Processing epoch 1779/2000
# Processing epoch 1780/2000
# Processing epoch 1781/2000
# Processing epoch 1782/2000
# Processing epoch 1783/2000
# Processing epoch 1784/2000
# Processing epoch 1785/2000
# Processing epoch 1786/2000
# Processing epoch 1787/2000
# Processing epoch 1788/2000
# Processing epoch 1789/2000
# Processing epoch 1790/2000
# Processing epoch 1791/2000
# Processing epoch 1792/2000
# Processing epoch 1793/2000
# Processing epoch 1794/2000
# Processing epoch 1795/2000
# Processing epoch 1796/2000
# Processing epoch 1797/2000
# Processing epoch 1798/2000
# Processing epoch 1799/2000
# Processing epoch 1800/2000
# Processing epoch 1801/2000
#
# Epoch 1801 completed
# Critic loss (average): -0.41576173589880067
# Generator loss (average): -0.997123183231912
#
# EMD (average): 0.007360837872567864
# ACF RMSE (average): 0.04682601439437258
# VOLATILITY RMSE (average): 0.28021150640386255
# LEVERAGE RMSE (average): 0.08454230745818447
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.036263240523918314 0.025001287359564108
# Min-Max values after Lambert:  -2.7668875331031164 1.8745259010357567
#
# Processing epoch 1802/2000
# Processing epoch 1803/2000
# Processing epoch 1804/2000
# Processing epoch 1805/2000
# Processing epoch 1806/2000
# Processing epoch 1807/2000
# Processing epoch 1808/2000
# Processing epoch 1809/2000
# Processing epoch 1810/2000
# Processing epoch 1811/2000
# Processing epoch 1812/2000
# Processing epoch 1813/2000
# Processing epoch 1814/2000
# Processing epoch 1815/2000
# Processing epoch 1816/2000
# Processing epoch 1817/2000
# Processing epoch 1818/2000
# Processing epoch 1819/2000
# Processing epoch 1820/2000
# Processing epoch 1821/2000
# Processing epoch 1822/2000
# Processing epoch 1823/2000
# Processing epoch 1824/2000
# Processing epoch 1825/2000
# Processing epoch 1826/2000
# Processing epoch 1827/2000
# Processing epoch 1828/2000
# Processing epoch 1829/2000
# Processing epoch 1830/2000
# Processing epoch 1831/2000
# Processing epoch 1832/2000
# Processing epoch 1833/2000
# Processing epoch 1834/2000
# Processing epoch 1835/2000
# Processing epoch 1836/2000
# Processing epoch 1837/2000
# Processing epoch 1838/2000
# Processing epoch 1839/2000
# Processing epoch 1840/2000
# Processing epoch 1841/2000
# Processing epoch 1842/2000
# Processing epoch 1843/2000
# Processing epoch 1844/2000
# Processing epoch 1845/2000
# Processing epoch 1846/2000
# Processing epoch 1847/2000
# Processing epoch 1848/2000
# Processing epoch 1849/2000
# Processing epoch 1850/2000
# Processing epoch 1851/2000
# Processing epoch 1852/2000
# Processing epoch 1853/2000
# Processing epoch 1854/2000
# Processing epoch 1855/2000
# Processing epoch 1856/2000
# Processing epoch 1857/2000
# Processing epoch 1858/2000
# Processing epoch 1859/2000
# Processing epoch 1860/2000
# Processing epoch 1861/2000
# Processing epoch 1862/2000
# Processing epoch 1863/2000
# Processing epoch 1864/2000
# Processing epoch 1865/2000
# Processing epoch 1866/2000
# Processing epoch 1867/2000
# Processing epoch 1868/2000
# Processing epoch 1869/2000
# Processing epoch 1870/2000
# Processing epoch 1871/2000
# Processing epoch 1872/2000
# Processing epoch 1873/2000
# Processing epoch 1874/2000
# Processing epoch 1875/2000
# Processing epoch 1876/2000
# Processing epoch 1877/2000
# Processing epoch 1878/2000
# Processing epoch 1879/2000
# Processing epoch 1880/2000
# Processing epoch 1881/2000
# Processing epoch 1882/2000
# Processing epoch 1883/2000
# Processing epoch 1884/2000
# Processing epoch 1885/2000
# Processing epoch 1886/2000
# Processing epoch 1887/2000
# Processing epoch 1888/2000
# Processing epoch 1889/2000
# Processing epoch 1890/2000
# Processing epoch 1891/2000
# Processing epoch 1892/2000
# Processing epoch 1893/2000
# Processing epoch 1894/2000
# Processing epoch 1895/2000
# Processing epoch 1896/2000
# Processing epoch 1897/2000
# Processing epoch 1898/2000
# Processing epoch 1899/2000
# Processing epoch 1900/2000
# Processing epoch 1901/2000
#
# Epoch 1901 completed
# Critic loss (average): -0.2963763813085035
# Generator loss (average): -1.3490240222900713
#
# EMD (average): 0.006129814526308608
# ACF RMSE (average): 0.046150643043418024
# VOLATILITY RMSE (average): 0.24998661201379763
# LEVERAGE RMSE (average): 0.07831945081706877
#
# Min-Max values of original log-returns:  -0.12765219747281709 0.10957196759533883
# Min-Max values of generated log-returns (for all batches):  -0.03443288570467526 0.025179786739474238
# Min-Max values after Lambert:  -2.628219469530786 1.888049051356543
#
# Processing epoch 1902/2000
# Processing epoch 1903/2000
# Processing epoch 1904/2000
# Processing epoch 1905/2000
# Processing epoch 1906/2000
# Processing epoch 1907/2000
# Processing epoch 1908/2000
# Processing epoch 1909/2000
# Processing epoch 1910/2000
# Processing epoch 1911/2000
# Processing epoch 1912/2000
# Processing epoch 1913/2000
# Processing epoch 1914/2000
# Processing epoch 1915/2000
# Processing epoch 1916/2000
# Processing epoch 1917/2000
# Processing epoch 1918/2000
# Processing epoch 1919/2000
# Processing epoch 1920/2000
# Processing epoch 1921/2000
# Processing epoch 1922/2000
# Processing epoch 1923/2000
# Processing epoch 1924/2000
# Processing epoch 1925/2000
# Processing epoch 1926/2000
# Processing epoch 1927/2000
# Processing epoch 1928/2000
# Processing epoch 1929/2000
# Processing epoch 1930/2000
# Processing epoch 1931/2000
# Processing epoch 1932/2000
# Processing epoch 1933/2000
# Processing epoch 1934/2000
# Processing epoch 1935/2000
# Processing epoch 1936/2000
# Processing epoch 1937/2000
# Processing epoch 1938/2000
# Processing epoch 1939/2000
# Processing epoch 1940/2000
# Processing epoch 1941/2000
# Processing epoch 1942/2000
# Processing epoch 1943/2000
# Processing epoch 1944/2000
# Processing epoch 1945/2000
# Processing epoch 1946/2000
# Processing epoch 1947/2000
# Processing epoch 1948/2000
# Processing epoch 1949/2000
# Processing epoch 1950/2000
# Processing epoch 1951/2000
# Processing epoch 1952/2000
# Processing epoch 1953/2000
# Processing epoch 1954/2000
# Processing epoch 1955/2000
# Processing epoch 1956/2000
# Processing epoch 1957/2000
# Processing epoch 1958/2000
# Processing epoch 1959/2000
# Processing epoch 1960/2000
# Processing epoch 1961/2000
# Processing epoch 1962/2000
# Processing epoch 1963/2000
# Processing epoch 1964/2000
# Processing epoch 1965/2000
# Processing epoch 1966/2000
# Processing epoch 1967/2000
# Processing epoch 1968/2000
# Processing epoch 1969/2000
# Processing epoch 1970/2000
# Processing epoch 1971/2000
# Processing epoch 1972/2000
# Processing epoch 1973/2000
# Processing epoch 1974/2000
# Processing epoch 1975/2000
# Processing epoch 1976/2000
# Processing epoch 1977/2000
# Processing epoch 1978/2000
# Processing epoch 1979/2000
# Processing epoch 1980/2000
# Processing epoch 1981/2000
# Processing epoch 1982/2000
# Processing epoch 1983/2000
# Processing epoch 1984/2000
# Processing epoch 1985/2000
# Processing epoch 1986/2000
# Processing epoch 1987/2000
# Processing epoch 1988/2000
# Processing epoch 1989/2000
# Processing epoch 1990/2000
# Processing epoch 1991/2000
# Processing epoch 1992/2000
# Processing epoch 1993/2000
# Processing epoch 1994/2000
# Processing epoch 1995/2000
# Processing epoch 1996/2000
# Processing epoch 1997/2000
# Processing epoch 1998/2000
# Processing epoch 1999/2000
# Processing epoch 2000/2000
#
# QGAN training completed. Training time: --- 28.67 hours ---

# %% [markdown]
# ## Plot Training History

# %%
critic_loss = tf.squeeze(qgan.critic_loss_avg, axis=(1,2)).numpy()
generator_loss = np.array(qgan.generator_loss_avg)

window = 50
generator_ma = np.convolve(generator_loss, np.ones(window)/window, mode='valid')
critic_ma = np.convolve(critic_loss, np.ones(window)/window, mode='valid')

# plot the graphs side-by-side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))

# plot the critic loss moving average as a line
axes[0].plot(range(window-1, len(critic_loss)), critic_ma, label='Average Critic Loss', color='blue')
# plot the critic loss
axes[0].plot(critic_loss, color='black', alpha=0.2)

# plot the generator loss moving average as a line
axes[0].plot(range(window-1, len(generator_loss)), generator_ma, label='Average Generator Loss', color='orange')
# plot the generator loss
axes[0].plot(generator_loss, color='black', alpha=0.2)


axes[0].set_ylabel('Loss')
axes[0].legend()
axes[0].grid()

emd_avg = np.array(qgan.emd_avg)
emd_ma = np.convolve(emd_avg, np.ones(window)/window, mode='valid')

axes[1].plot(range(window-1, len(emd_avg)), emd_ma, label='EMD', color='red')
axes[1].plot(emd_avg, color='red', linewidth=0.5, alpha=0.5)

axes[1].set_ylabel('EMD')
axes[1].legend()
axes[1].grid()

acf_avg = np.array(qgan.acf_avg)
vol_avg = np.array(qgan.vol_avg)
lev_avg = np.array(qgan.lev_avg)

acf_ma = np.convolve(acf_avg, np.ones(window)/window, mode='valid')
vol_ma = np.convolve(vol_avg, np.ones(window)/window, mode='valid')
lev_ma = np.convolve(lev_avg, np.ones(window)/window, mode='valid')

# Creating a twin axes for the second graph
axes2 = axes[1].twinx()

axes2.plot(range(window-1, len(acf_avg)), acf_ma, label='ACF', color='green')
axes2.plot(acf_avg, color='green', linewidth=0.5, alpha=0.4)

axes2.plot(range(window-1, len(vol_avg)), vol_ma, label='Volatility Clustering', color='black')
axes2.plot(vol_avg, color='black', linewidth=0.5, alpha=0.3)

axes2.plot(range(window-1, len(lev_avg)), lev_ma, label='Leverage Effect', color='orange')

axes2.set_ylabel('Temporal Metrics')
axes2.legend()
axes2.grid()

# Adjusting the spacing between subplots
plt.tight_layout()

# %% [markdown]
# ## Plot Generated Data Properties

# %%
# generate noise
num_samples = len(sp500_log_r_tf) // WINDOW_LENGTH
input_circuits_batch = []
for _ in range(num_samples):
    noise_values = np.random.uniform(0, 2 * np.pi, size=NUM_QUBITS)
    input_circuits_batch.append(qgan.encoding_layer(noise_values))
    
# convert to tensorflow quantum tensor
generator_inputs = tfq.convert_to_tensor(input_circuits_batch)
# generate fake samples using the generator
batch_generated = qgan.generator(generator_inputs)
# concatenate all time series data into one
generated_data = tf.reshape(batch_generated, shape=(num_samples*WINDOW_LENGTH,))
generated_data = tf.cast(generated_data, dtype=tf.float64)
# rescale
generated_data = rescale(generated_data, transformed_sp500)
# reverse the preprocessing on generated sample
original_norm = lambert_w_transform(generated_data, 1)
fake_original = denormalize(original_norm, tf.reduce_mean(sp500_log_r_tf), tf.math.reduce_std(sp500_log_r_tf))

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
###################################################################################################################
#
# plot original log-returns on the left and the generated on the right
#
###################################################################################################################
axes[0].plot(date[1:], sp500_log_r_tf)
axes[0].set_xlabel('Days')
axes[0].set_title('Original Log-Returns')
axes[0].grid()

axes[1].plot(fake_original)
axes[1].set_xlabel('Days')
axes[1].set_title('Generated Log-Returns')
axes[1].grid()

plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
###################################################################################################################
#
# plot histogram of generated along with original log-returns on the left and the Q-Q plot on the right
#
###################################################################################################################
bin_edges = np.linspace(-0.05, 0.05, num=50)  # define the bin edges
bin_width = bin_edges[1] - bin_edges[0]
bin_edges = np.append(bin_edges, bin_edges[-1] + bin_width)
axes[0].hist(fake_original, bins=bin_edges, density=True, width=0.001, label='Generated', alpha=0.9)
axes[0].hist(sp500_log_r_tf, bins=bin_edges, density=True, width=0.001, label='Original', alpha=0.8)
axes[0].set_title('Original vs Generated Density')
axes[0].grid()
axes[0].legend()

probplot(fake_original, dist='norm', plot=axes[1])
axes[1].set_xlabel('Theoretical Quantiles')
axes[1].grid()

plt.subplots_adjust(wspace=0.3)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
###################################################################################################################
#
# plot autocorrelations of original log-returns on the left and the generated on the right
#
###################################################################################################################
tsaplots.plot_acf(sp500_log_r_tf, ax=axes[0], lags=18, zero=False)
axes[0].set_xlabel('Lags')
axes[0].set_title('ACF Log-Returns')
axes[0].grid()

tsaplots.plot_acf(fake_original, ax=axes[1], lags=18, zero=False)
axes[1].set_xlabel('Lags')
axes[1].set_title('ACF Log-Returns (Generated)')
axes[1].grid()

plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
###################################################################################################################
#
# plot volatility clustering of original log-returns on the left and the generated on the right
#
###################################################################################################################
tsaplots.plot_acf(tf.abs(sp500_log_r_tf), ax=axes[0], lags=18, zero=False)
axes[0].set_xlabel('Lags')
axes[0].set_title('ACF Absolute Log-Returns')
axes[0].grid()

tsaplots.plot_acf(tf.abs(fake_original), ax=axes[1], lags=18, zero=False)
axes[1].set_xlabel('Lags')
axes[1].set_title('ACF Absolute Log-Returns (Generated)')
axes[1].grid()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
###################################################################################################################
#
# plot leverage effect of original log-returns on the left and the generated on the right
#
###################################################################################################################
# compute leverage effect for maximum lags = 18
leverage_original = []
for lag in range(1, 19):
    # slice the tensors to get the appropriate lagged sequences
    r_t = sp500_log_r_tf[:-lag]
    squared_lag_r = tf.square(tf.abs(sp500_log_r_tf[lag:]))
                       
    # calculate the leverage effect
    # calculate the correlation coefficient
    correlation_matrix = np.corrcoef(r_t, squared_lag_r)
    leverage_original.append(correlation_matrix[0, 1])
    
leverage_generated = []
for lag in range(1, 19):
    # slice the tensors to get the appropriate lagged sequences
    r_t = fake_original[:-lag]
    squared_lag_r = tf.square(tf.abs(fake_original[lag:]))
                
    # calculate the leverage effect
    # calculate the correlation coefficient
    correlation_matrix = np.corrcoef(r_t, squared_lag_r)
    leverage_generated.append(correlation_matrix[0, 1])

axes[0].plot(leverage_original)
axes[0].set_xlabel('Lags')
axes[0].set_title('Original Leverage Effect')
axes[0].grid()

axes[1].plot(leverage_generated)
axes[1].set_xlabel('Lags')
axes[1].set_title('Generated Leverage Effect')
axes[1].grid()
